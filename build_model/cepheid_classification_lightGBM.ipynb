# %%
import numpy as np
import joblib
import os
import pandas as pd

# 使用网格搜索方法来进行参数选择
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import LabelEncoder

from collections import Counter
# 使用StratifiedShuffleSplit类进行分层抽样
from imblearn.over_sampling import SMOTE, ADASYN, BorderlineSMOTE, SVMSMOTE, KMeansSMOTE
from data_process.light_curve import ASASLightCurve

# 使用StratifiedShuffleSplit类进行分层抽样
from sklearn.model_selection import train_test_split

# %%
full_lc_pd = pd.read_csv("../dataset/light_curve_dataframe/cepheid/lc_cepheid.csv")

# %%
# delete_idx = full_lc_pd[full_lc_pd["peri_optical"].isnull() == True].index
# full_lc_pd = full_lc_pd.drop(delete_idx)

# %%
sub_class = full_lc_pd["variable_type"]
features_drop_unlabel = full_lc_pd.drop(
    labels=["source_id", "class_probability", "variable_type", "created_at", "main_type", "updated_at", "mean_vmag",
            "lksl_statistic", "rfr_score", "epoch_hjd", "e_b_v", "vector_x", "vector_y", "vector_z", "periodic"],
    axis=1)
features_drop_unlabel = features_drop_unlabel.dropna(axis=1)
features_drop_unlabel
# Out:
#         raj2000   dej2000          l         b  amplitude     period  \
# 0     310.79987  67.24633  102.21333  15.02330       0.35   3.926633
# 1      77.32044 -64.70331  274.78448 -35.18470       0.36   2.088684
# 2      77.32044 -64.70331  274.78448 -35.18470       0.36   2.088684
# 3     294.76155  24.38494   59.88100   1.20807       0.58   5.171102
# 4     218.81848 -67.37944  312.68775  -6.49576       1.05   2.242517
# ...         ...       ...        ...       ...        ...        ...
# 4643   82.31937 -67.47275  277.68457 -32.73992       0.87  13.420894
# 4644  273.47423 -64.60680  329.77829 -20.46853       1.20   1.730097
# 4645   81.16232 -66.43103  276.52916 -33.33331       0.50   8.926746
# 4646   81.16232 -66.43103  276.52916 -33.33331       0.50   8.926746
# 4647  282.06813   0.81761   33.29884   1.07706       0.67   4.400497
#
#            mean   median       std  skewness  ...  phase_eta  peri_optical  \
# 0     12.624732  12.6440  0.119334 -0.293535  ...   0.034235      3.215154
# 1     15.190610  15.1960  0.113792 -0.030457  ...   0.348689      7.272814
# 2     15.181465  15.1960  0.112264 -0.094424  ...   0.393449      7.268436
# 3     14.729574  14.7665  0.195464 -0.056890  ...   0.099079      2.848440
# 4     16.050593  16.0630  0.327898  0.106559  ...   0.496881      7.157402
# ...         ...      ...       ...       ...  ...        ...           ...
# 4643  14.071352  14.0730  0.251560 -0.314950  ...   0.037554      1.048466
# 4644  14.195057  14.2030  0.347610 -0.332813  ...   0.127093      8.204774
# 4645  14.830084  14.8200  0.158128  0.148821  ...   0.154566      1.661309
# 4646  14.840917  14.8200  0.162239  0.208626  ...   0.131675      1.662523
# 4647  11.333400  11.3815  0.220993 -0.379488  ...   0.007669      2.575482
#
#       pearsonr  Mm_period_ratio        l1  slope_per10  slope_per90  \
# 0     0.817310         0.445488  0.958295    -5.687144     8.008793
# 1    -0.803812         0.369049  0.830162    -0.937212     0.662440
# 2    -0.782158         0.201067  0.807894    -0.381057     0.363685
# 3     0.747205         0.652410  0.942369    -2.501995     3.541191
# 4     0.562861         0.266138  0.792623    -0.268636     0.205061
# ...        ...              ...       ...          ...          ...
# 4643  0.938600         0.454573  0.974491    -3.270565     3.443486
# 4644 -0.409689         0.202314  0.940084    -0.363470     0.910712
# 4645 -0.471253         0.682410  0.925440    -5.456310     2.382115
# 4646 -0.860432         0.711840  0.937132    -1.908869     1.647371
# 4647 -0.940666         0.745545  0.995629    -4.999828     5.935297
#
#       slope_per20  slope_per80  phase_cusum
# 0       -1.898098     3.878650     0.436784
# 1       -0.394233     0.340217     0.456209
# 2       -0.140914     0.178288     0.435883
# 3       -0.933468     1.772922     0.510828
# 4       -0.112563     0.114487     0.292923
# ...           ...          ...          ...
# 4643    -1.536690     1.231369     0.382776
# 4644    -0.166356     0.450779     0.483828
# 4645    -2.305983     1.216406     0.488884
# 4646    -0.872921     0.851560     0.500447
# 4647    -1.315622     3.866999     0.443097
#
# [4648 rows x 80 columns]

# %%
label_encoder = LabelEncoder()
sub_class = label_encoder.fit_transform(sub_class)
sub_class = sub_class.astype(np.int32)

# %%
np.random.seed(1)
X_train, X_test, y_train, y_test = train_test_split(features_drop_unlabel, sub_class, test_size=0.2, shuffle=True,
                                                    random_state=0)
# X_train, y_train = SMOTE().fit_resample(X_train, y_train)
X_train, y_train = ADASYN().fit_resample(X_train, y_train)
print(sorted(Counter(y_train).items()))
# Out:
# [(0, 1656), (1, 1607), (2, 1633), (3, 1715), (4, 1635)]

# %%
import lightgbm as lgb

param_grid = [
    {'n_estimators': [180,200]},
]

clf = lgb.LGBMClassifier(learning_rate=0.01)
grid_search = GridSearchCV(clf, param_grid, cv=5, scoring="accuracy", return_train_score=True, verbose=10)

grid_search.fit(X_train, y_train)
print(grid_search.best_params_)
print(grid_search.best_estimator_)
print(grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5; 1/2] START n_estimators=180............................................
# [CV 1/5; 1/2] END n_estimators=180;, score=(train=0.973, test=0.910) total time=   1.6s
# [CV 2/5; 1/2] START n_estimators=180............................................
# [CV 2/5; 1/2] END n_estimators=180;, score=(train=0.969, test=0.928) total time=   2.2s
# [CV 3/5; 1/2] START n_estimators=180............................................
# [CV 3/5; 1/2] END n_estimators=180;, score=(train=0.967, test=0.918) total time=   1.6s
# [CV 4/5; 1/2] START n_estimators=180............................................
# [CV 4/5; 1/2] END n_estimators=180;, score=(train=0.969, test=0.912) total time=   1.6s
# [CV 5/5; 1/2] START n_estimators=180............................................
# [CV 5/5; 1/2] END n_estimators=180;, score=(train=0.969, test=0.920) total time=   1.7s
# [CV 1/5; 2/2] START n_estimators=200............................................
# [CV 1/5; 2/2] END n_estimators=200;, score=(train=0.977, test=0.912) total time=   1.6s
# [CV 2/5; 2/2] START n_estimators=200............................................
# [CV 2/5; 2/2] END n_estimators=200;, score=(train=0.973, test=0.932) total time=   1.7s
# [CV 3/5; 2/2] START n_estimators=200............................................
# [CV 3/5; 2/2] END n_estimators=200;, score=(train=0.972, test=0.919) total time=   1.7s
# [CV 4/5; 2/2] START n_estimators=200............................................
# [CV 4/5; 2/2] END n_estimators=200;, score=(train=0.974, test=0.916) total time=   1.8s
# [CV 5/5; 2/2] START n_estimators=200............................................
# [CV 5/5; 2/2] END n_estimators=200;, score=(train=0.974, test=0.922) total time=   1.7s
# {'n_estimators': 200}
# LGBMClassifier(learning_rate=0.01, n_estimators=200)
# 0.9204472866934965

# %%
grid_search.score(X_test, y_test)
# Out:
# 0.8698924731182796

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# 0.9177792234044508 {'n_estimators': 180}
# 0.9204472866934965 {'n_estimators': 200}

# %%
# 计算每种特征对分类结果的影响
feature_name = features_drop_unlabel.columns
feature_importances = grid_search.best_estimator_.feature_importances_
sorted(zip(feature_importances, feature_name), reverse=True)
# Out:
# [(3474, 'period'),
#  (1997, 'b'),
#  (1521, 'raj2000'),
#  (1263, 'b2'),
#  (1237, 'r21'),
#  (1154, 'l'),
#  (1046, 'peri_optical'),
#  (1022, 'mean'),
#  (1004, 'dej2000'),
#  (787, 'b1'),
#  (669, 'amplitude'),
#  (451, 'phi21'),
#  (436, 'hl_amp_ratio'),
#  (424, 'shapiro_w'),
#  (412, 'phase_eta'),
#  (402, 'b3'),
#  (394, 'skewness'),
#  (382, 'MAD'),
#  (353, 'l1'),
#  (335, 'r31'),
#  (331, 'a21'),
#  (329, 'a3'),
#  (322, 'h_1'),
#  (319, 'phi32'),
#  (315, 'r41'),
#  (314, 'pearsonr'),
#  (313, 'slope_per20'),
#  (309, 'median'),
#  (267, 'slope_per10'),
#  (266, 'b31'),
#  (264, 'IQR'),
#  (263, 'b4'),
#  (262, 'kurtosis'),
#  (253, 'b43'),
#  (249, 'std'),
#  (241, 'b32'),
#  (234, 'slope_per90'),
#  (227, 'a2'),
#  (226, 'phi31'),
#  (223, 'b41'),
#  (213, 'phase_cusum'),
#  (209, 'a31'),
#  (197, 'r43'),
#  (195, 'b21'),
#  (193, 'stetson_k'),
#  (193, 'a42'),
#  (192, 'a32'),
#  (187, 'slope_per80'),
#  (185, 'Mm_ratio'),
#  (178, 'r53'),
#  (176, 'b51'),
#  (170, 'r32'),
#  (166, 'a5'),
#  (165, 'b42'),
#  (162, 'b53'),
#  (161, 'Mm_period_ratio'),
#  (149, 'b5'),
#  (147, 'p2p'),
#  (146, 'r54'),
#  (141, 'phi52'),
#  (136, 'phi42'),
#  (136, 'a53'),
#  (134, 'r42'),
#  (131, 'f_phase'),
#  (130, 'a4'),
#  (124, 'a43'),
#  (118, 'phi53'),
#  (115, 'r52'),
#  (115, 'b54'),
#  (109, 'a1'),
#  (105, 'b52'),
#  (104, 'a51'),
#  (103, 'a52'),
#  (101, 'phi43'),
#  (99, 'phi54'),
#  (98, 'a41'),
#  (90, 'a54'),
#  (86, 'phi51'),
#  (74, 'phi41'),
#  (61, 'r51')]

# %%
import matplotlib.pyplot as plt

importances = sorted(zip(feature_importances, feature_name), reverse=True)
feature_im = []
feature_n = []
for i in importances:
    feature_im.append(i[0])
    feature_n.append(i[1])
plt.figure(figsize=(20, 10))
indexes = np.arange(len(feature_im))
plt.title("Influence of different indexes on classification accuracy", fontsize=20)
plt.xlabel("Different feature indexes", fontsize=16)
plt.ylabel("Feature importances", fontsize=16)
plt.bar(2 * indexes, feature_im, 2, edgecolor="black", alpha=0.7, color=['r', 'g', 'b', 'y', 'pink'])
plt.xticks(2 * indexes + 2 * 0.2, feature_n, rotation=90)
plt.show()
plt.savefig(f"./output/feature_important/random_forest_cepheids_importance_{grid_search.best_score_}.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [28], line 17
#      15 plt.xticks(2 * indexes + 2 * 0.2, feature_n, rotation=90)
#      16 plt.show()
# ---> 17 plt.savefig(f"./output/feature_important/random_forest_cepheids_importance_{grid_search.best_score_}.png")
#
# File D:\ProgramSoftware\Anaconda\envs\sklearn-py310\lib\site-packages\matplotlib\pyplot.py:954, in savefig(*args, **kwargs)
#     951 @_copy_docstring_and_deprecators(Figure.savefig)
#     952 def savefig(*args, **kwargs):
#     953     fig = gcf()
# --> 954     res = fig.savefig(*args, **kwargs)
#     955     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     956     return res
#
# File D:\ProgramSoftware\Anaconda\envs\sklearn-py310\lib\site-packages\matplotlib\figure.py:3274, in Figure.savefig(self, fname, transparent, **kwargs)
#    3270     for ax in self.axes:
#    3271         stack.enter_context(
#    3272             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3274 self.canvas.print_figure(fname, **kwargs)
#
# File D:\ProgramSoftware\Anaconda\envs\sklearn-py310\lib\site-packages\matplotlib\backend_bases.py:2338, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2334 try:
#    2335     # _get_renderer may change the figure dpi (as vector formats
#    2336     # force the figure dpi to 72), so we need to set it again here.
#    2337     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2338         result = print_method(
#    2339             filename,
#    2340             facecolor=facecolor,
#    2341             edgecolor=edgecolor,
#    2342             orientation=orientation,
#    2343             bbox_inches_restore=_bbox_inches_restore,
#    2344             **kwargs)
#    2345 finally:
#    2346     if bbox_inches and restore_bbox:
#
# File D:\ProgramSoftware\Anaconda\envs\sklearn-py310\lib\site-packages\matplotlib\backend_bases.py:2204, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2200     optional_kws = {  # Passed by print_figure for other renderers.
#    2201         "dpi", "facecolor", "edgecolor", "orientation",
#    2202         "bbox_inches_restore"}
#    2203     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2204     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2205         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2206 else:  # Let third-parties do as they see fit.
#    2207     print_method = meth
#
# File D:\ProgramSoftware\Anaconda\envs\sklearn-py310\lib\site-packages\matplotlib\_api\deprecation.py:410, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     400     deprecation_addendum = (
#     401         f"If any parameter follows {name!r}, they should be passed as "
#     402         f"keyword, not positionally.")
#     403     warn_deprecated(
#     404         since,
#     405         name=repr(name),
#    (...)
#     408                  else deprecation_addendum,
#     409         **kwargs)
# --> 410 return func(*inner_args, **inner_kwargs)
#
# File D:\ProgramSoftware\Anaconda\envs\sklearn-py310\lib\site-packages\matplotlib\backends\backend_agg.py:517, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     468 @_api.delete_parameter("3.5", "args")
#     469 def print_png(self, filename_or_obj, *args,
#     470               metadata=None, pil_kwargs=None):
#     471     """
#     472     Write the figure to a PNG file.
#     473
#    (...)
#     515         *metadata*, including the default 'Software' key.
#     516     """
# --> 517     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File D:\ProgramSoftware\Anaconda\envs\sklearn-py310\lib\site-packages\matplotlib\backends\backend_agg.py:464, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     459 """
#     460 Draw the canvas, then save it using `.image.imsave` (to which
#     461 *pil_kwargs* and *metadata* are forwarded).
#     462 """
#     463 FigureCanvasAgg.draw(self)
# --> 464 mpl.image.imsave(
#     465     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     466     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File D:\ProgramSoftware\Anaconda\envs\sklearn-py310\lib\site-packages\matplotlib\image.py:1664, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1662 pil_kwargs.setdefault("format", format)
#    1663 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1664 image.save(fname, **pil_kwargs)
#
# File D:\ProgramSoftware\Anaconda\envs\sklearn-py310\lib\site-packages\PIL\Image.py:2350, in Image.save(self, fp, format, **params)
#    2348         fp = builtins.open(filename, "r+b")
#    2349     else:
# -> 2350         fp = builtins.open(filename, "w+b")
#    2352 try:
#    2353     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: './output/feature_important/random_forest_cepheids_importance_0.9204472866934965.png'

# %%
# from my_util.utils import plot_confusion_matrix
import seaborn as sns
from sklearn.metrics import confusion_matrix

y_pred = grid_search.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

classes = np.unique(np.concatenate([np.array(y_test), np.array(y_pred)]))
classes = label_encoder.inverse_transform(classes)
plt.figure(figsize=(10, 10), dpi=300)

heatmap = sns.heatmap(cm, annot=True, fmt='d', cmap=plt.cm.Blues)
heatmap.yaxis.set_ticklabels(classes, rotation=0, ha='right')
heatmap.xaxis.set_ticklabels(classes, rotation=45, ha='right')
# plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Cepheid Variable Classification Confusion Matrix (XGBoost+SVMSMOTE)')
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [29], line 17
#      15 # plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
#      16 plt.title('Cepheid Variable Classification Confusion Matrix (XGBoost+SVMSMOTE)')
# ---> 17 plt.colorbar()
#      18 tick_marks = np.arange(len(classes))
#      19 plt.xticks(tick_marks, classes, rotation=45)
#
# File D:\ProgramSoftware\Anaconda\envs\sklearn-py310\lib\site-packages\matplotlib\pyplot.py:2061, in colorbar(mappable, cax, ax, **kwargs)
#    2059     mappable = gci()
#    2060     if mappable is None:
# -> 2061         raise RuntimeError('No mappable was found to use for colorbar '
#    2062                            'creation. First define a mappable such as '
#    2063                            'an image (with imshow) or a contour set ('
#    2064                            'with contourf).')
#    2065 ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
#    2066 return ret
#
# RuntimeError: No mappable was found to use for colorbar creation. First define a mappable such as an image (with imshow) or a contour set (with contourf).

# %%
from sklearn.metrics import recall_score, precision_score, f1_score, classification_report

print(recall_score(y_test, y_pred, average='macro'))
print(f1_score(y_test, y_pred, average='macro'))
print(precision_score(y_test, y_pred, average='macro'))
print(recall_score(y_test, y_pred, average='macro'))
print(classification_report(y_test, y_pred, target_names=classes, digits=4))
# Out:
# 0.9070683915640588
# 0.8910928717897096
# 0.8812245667368387
# 0.9070683915640588
#               precision    recall  f1-score   support
#
#          CWA     0.8280    0.9872    0.9006       156
#          CWB     0.7850    0.8528    0.8175       197
#         DCEP     0.9255    0.7863    0.8502       379
#        DCEPS     0.8909    0.9545    0.9216       154
#          RVA     0.9767    0.9545    0.9655        44
#
#     accuracy                         0.8699       930
#    macro avg     0.8812    0.9071    0.8911       930
# weighted avg     0.8761    0.8699    0.8690       930

# %%
joblib.dump(label_encoder, f"./output/label_encoder/cepheids_label_{grid_search.best_score_}.pkl")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [97], in <cell line: 1>()
# ----> 1 joblib.dump(label_encoder, f"./output/label_encoder/cepheids_label_{grid_search.best_score_}.pkl")
#
# File D:\program_software\Anaconda\envs\tf2-py39\lib\site-packages\joblib\numpy_pickle.py:481, in dump(value, filename, compress, protocol, cache_size)
#     479         NumpyPickler(f, protocol=protocol).dump(value)
#     480 elif is_filename:
# --> 481     with open(filename, 'wb') as f:
#     482         NumpyPickler(f, protocol=protocol).dump(value)
#     483 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: './output/label_encoder/cepheids_label_0.9873653937708639.pkl'

# %%
root = os.getcwd().split("train")[0]
features_root = os.path.join(root, "datasets", "new_astronomy_lc_features_v1")
full_lc = np.load(os.path.join(features_root, "cepheids_var.npy"), allow_pickle=True)
full_lc_list = full_lc.tolist()
full_lc_pd = pd.DataFrame(full_lc_list)
full_lc_pd = full_lc_pd[full_lc_pd["class_probability"] >= 0.95]

sub_class = full_lc_pd["type"]
features_drop_unlabel = full_lc_pd[useful_feature_cepheids_new]
features_drop_unlabel = features_drop_unlabel.drop(labels=["class_probability", "type"], axis=1)
features_drop_unlabel = features_drop_unlabel.dropna(axis=1)

label_encoder = LabelEncoder()
sub_class = label_encoder.fit_transform(sub_class)
sub_class = sub_class.astype(np.int32)

np.random.seed(42)
# 0:92204
# 1:9005 2:905913  3:9139  4:90322 5:93817  6:87903
X_train, X_test, y_train, y_test = train_test_split(features_drop_unlabel, sub_class, test_size=0.2,
                                                    shuffle=True, random_state=5)
X_train, y_train = SMOTE().fit_resample(X_train, y_train)
print(sorted(Counter(y_train).items()))

param_grid = [
    {'n_estimators': range(10, 31, 5), 'max_features': range(10, 51, 5)},
    {'bootstrap': [False], 'n_estimators': range(10, 31, 5), 'max_features': range(10, 51, 5)}
]
clf = RandomForestClassifier(n_jobs=-1)
grid_search_new = GridSearchCV(clf, param_grid, cv=5, scoring="accuracy", return_train_score=True, verbose=10)

grid_search_new.fit(X_train, y_train)
print(grid_search_new.best_params_)
print(grid_search_new.best_estimator_)
print(grid_search_new.best_score_)
grid_search_new.score(X_test, y_test)
# Out:
# [(0, 1005), (1, 1005), (2, 1005), (3, 1005), (4, 1005)]
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# [CV 1/5; 1/90] START max_features=10, n_estimators=10...........................
# [CV 1/5; 1/90] END max_features=10, n_estimators=10;, score=(train=0.999, test=0.959) total time=   0.0s
# [CV 2/5; 1/90] START max_features=10, n_estimators=10...........................
# [CV 2/5; 1/90] END max_features=10, n_estimators=10;, score=(train=0.998, test=0.958) total time=   0.0s
# [CV 3/5; 1/90] START max_features=10, n_estimators=10...........................
# [CV 3/5; 1/90] END max_features=10, n_estimators=10;, score=(train=0.999, test=0.977) total time=   0.0s
# [CV 4/5; 1/90] START max_features=10, n_estimators=10...........................
# [CV 4/5; 1/90] END max_features=10, n_estimators=10;, score=(train=0.999, test=0.972) total time=   0.0s
# [CV 5/5; 1/90] START max_features=10, n_estimators=10...........................
# [CV 5/5; 1/90] END max_features=10, n_estimators=10;, score=(train=0.999, test=0.968) total time=   0.0s
# [CV 1/5; 2/90] START max_features=10, n_estimators=15...........................
# [CV 1/5; 2/90] END max_features=10, n_estimators=15;, score=(train=1.000, test=0.968) total time=   0.0s
# [CV 2/5; 2/90] START max_features=10, n_estimators=15...........................
# [CV 2/5; 2/90] END max_features=10, n_estimators=15;, score=(train=1.000, test=0.972) total time=   0.0s
# [CV 3/5; 2/90] START max_features=10, n_estimators=15...........................
# [CV 3/5; 2/90] END max_features=10, n_estimators=15;, score=(train=1.000, test=0.978) total time=   0.0s
# [CV 4/5; 2/90] START max_features=10, n_estimators=15...........................
# [CV 4/5; 2/90] END max_features=10, n_estimators=15;, score=(train=1.000, test=0.979) total time=   0.0s
# [CV 5/5; 2/90] START max_features=10, n_estimators=15...........................
# [CV 5/5; 2/90] END max_features=10, n_estimators=15;, score=(train=1.000, test=0.973) total time=   0.0s
# [CV 1/5; 3/90] START max_features=10, n_estimators=20...........................
# [CV 1/5; 3/90] END max_features=10, n_estimators=20;, score=(train=1.000, test=0.969) total time=   0.0s
# [CV 2/5; 3/90] START max_features=10, n_estimators=20...........................
# [CV 2/5; 3/90] END max_features=10, n_estimators=20;, score=(train=1.000, test=0.975) total time=   0.0s
# [CV 3/5; 3/90] START max_features=10, n_estimators=20...........................
# [CV 3/5; 3/90] END max_features=10, n_estimators=20;, score=(train=1.000, test=0.977) total time=   0.0s
# [CV 4/5; 3/90] START max_features=10, n_estimators=20...........................
# [CV 4/5; 3/90] END max_features=10, n_estimators=20;, score=(train=1.000, test=0.985) total time=   0.0s
# [CV 5/5; 3/90] START max_features=10, n_estimators=20...........................
# [CV 5/5; 3/90] END max_features=10, n_estimators=20;, score=(train=1.000, test=0.969) total time=   0.0s
# [CV 1/5; 4/90] START max_features=10, n_estimators=25...........................
# [CV 1/5; 4/90] END max_features=10, n_estimators=25;, score=(train=1.000, test=0.972) total time=   0.1s
# [CV 2/5; 4/90] START max_features=10, n_estimators=25...........................
# [CV 2/5; 4/90] END max_features=10, n_estimators=25;, score=(train=1.000, test=0.974) total time=   0.1s
# [CV 3/5; 4/90] START max_features=10, n_estimators=25...........................
# [CV 3/5; 4/90] END max_features=10, n_estimators=25;, score=(train=1.000, test=0.979) total time=   0.1s
# [CV 4/5; 4/90] START max_features=10, n_estimators=25...........................
# [CV 4/5; 4/90] END max_features=10, n_estimators=25;, score=(train=1.000, test=0.979) total time=   0.1s
# [CV 5/5; 4/90] START max_features=10, n_estimators=25...........................
# [CV 5/5; 4/90] END max_features=10, n_estimators=25;, score=(train=1.000, test=0.977) total time=   0.1s
# [CV 1/5; 5/90] START max_features=10, n_estimators=30...........................
# [CV 1/5; 5/90] END max_features=10, n_estimators=30;, score=(train=1.000, test=0.974) total time=   0.1s
# [CV 2/5; 5/90] START max_features=10, n_estimators=30...........................
# [CV 2/5; 5/90] END max_features=10, n_estimators=30;, score=(train=1.000, test=0.978) total time=   0.1s
# [CV 3/5; 5/90] START max_features=10, n_estimators=30...........................
# [CV 3/5; 5/90] END max_features=10, n_estimators=30;, score=(train=1.000, test=0.979) total time=   0.1s
# [CV 4/5; 5/90] START max_features=10, n_estimators=30...........................
# [CV 4/5; 5/90] END max_features=10, n_estimators=30;, score=(train=1.000, test=0.981) total time=   0.1s
# [CV 5/5; 5/90] START max_features=10, n_estimators=30...........................
# [CV 5/5; 5/90] END max_features=10, n_estimators=30;, score=(train=1.000, test=0.971) total time=   0.1s
# [CV 1/5; 6/90] START max_features=15, n_estimators=10...........................
# [CV 1/5; 6/90] END max_features=15, n_estimators=10;, score=(train=0.999, test=0.958) total time=   0.0s
# [CV 2/5; 6/90] START max_features=15, n_estimators=10...........................
# [CV 2/5; 6/90] END max_features=15, n_estimators=10;, score=(train=0.998, test=0.956) total time=   0.0s
# [CV 3/5; 6/90] START max_features=15, n_estimators=10...........................
# [CV 3/5; 6/90] END max_features=15, n_estimators=10;, score=(train=0.999, test=0.974) total time=   0.0s
# [CV 4/5; 6/90] START max_features=15, n_estimators=10...........................
# [CV 4/5; 6/90] END max_features=15, n_estimators=10;, score=(train=0.999, test=0.973) total time=   0.0s
# [CV 5/5; 6/90] START max_features=15, n_estimators=10...........................
# [CV 5/5; 6/90] END max_features=15, n_estimators=10;, score=(train=0.998, test=0.963) total time=   0.0s
# [CV 1/5; 7/90] START max_features=15, n_estimators=15...........................
# [CV 1/5; 7/90] END max_features=15, n_estimators=15;, score=(train=0.999, test=0.967) total time=   0.0s
# [CV 2/5; 7/90] START max_features=15, n_estimators=15...........................
# [CV 2/5; 7/90] END max_features=15, n_estimators=15;, score=(train=0.999, test=0.970) total time=   0.0s
# [CV 3/5; 7/90] START max_features=15, n_estimators=15...........................
# [CV 3/5; 7/90] END max_features=15, n_estimators=15;, score=(train=1.000, test=0.975) total time=   0.0s
# [CV 4/5; 7/90] START max_features=15, n_estimators=15...........................
# [CV 4/5; 7/90] END max_features=15, n_estimators=15;, score=(train=1.000, test=0.972) total time=   0.0s
# [CV 5/5; 7/90] START max_features=15, n_estimators=15...........................
# [CV 5/5; 7/90] END max_features=15, n_estimators=15;, score=(train=1.000, test=0.966) total time=   0.0s
# [CV 1/5; 8/90] START max_features=15, n_estimators=20...........................
# [CV 1/5; 8/90] END max_features=15, n_estimators=20;, score=(train=1.000, test=0.966) total time=   0.0s
# [CV 2/5; 8/90] START max_features=15, n_estimators=20...........................
# [CV 2/5; 8/90] END max_features=15, n_estimators=20;, score=(train=0.999, test=0.971) total time=   0.1s
# [CV 3/5; 8/90] START max_features=15, n_estimators=20...........................
# [CV 3/5; 8/90] END max_features=15, n_estimators=20;, score=(train=1.000, test=0.979) total time=   0.1s
# [CV 4/5; 8/90] START max_features=15, n_estimators=20...........................
# [CV 4/5; 8/90] END max_features=15, n_estimators=20;, score=(train=0.999, test=0.978) total time=   0.1s
# [CV 5/5; 8/90] START max_features=15, n_estimators=20...........................
# [CV 5/5; 8/90] END max_features=15, n_estimators=20;, score=(train=1.000, test=0.971) total time=   0.1s
# [CV 1/5; 9/90] START max_features=15, n_estimators=25...........................
# [CV 1/5; 9/90] END max_features=15, n_estimators=25;, score=(train=1.000, test=0.970) total time=   0.1s
# [CV 2/5; 9/90] START max_features=15, n_estimators=25...........................
# [CV 2/5; 9/90] END max_features=15, n_estimators=25;, score=(train=1.000, test=0.968) total time=   0.1s
# [CV 3/5; 9/90] START max_features=15, n_estimators=25...........................
# [CV 3/5; 9/90] END max_features=15, n_estimators=25;, score=(train=1.000, test=0.981) total time=   0.1s
# [CV 4/5; 9/90] START max_features=15, n_estimators=25...........................
# [CV 4/5; 9/90] END max_features=15, n_estimators=25;, score=(train=0.999, test=0.982) total time=   0.1s
# [CV 5/5; 9/90] START max_features=15, n_estimators=25...........................
# [CV 5/5; 9/90] END max_features=15, n_estimators=25;, score=(train=1.000, test=0.968) total time=   0.1s
# [CV 1/5; 10/90] START max_features=15, n_estimators=30..........................
# [CV 1/5; 10/90] END max_features=15, n_estimators=30;, score=(train=1.000, test=0.973) total time=   0.1s
# [CV 2/5; 10/90] START max_features=15, n_estimators=30..........................
# [CV 2/5; 10/90] END max_features=15, n_estimators=30;, score=(train=1.000, test=0.969) total time=   0.1s
# [CV 3/5; 10/90] START max_features=15, n_estimators=30..........................
# [CV 3/5; 10/90] END max_features=15, n_estimators=30;, score=(train=1.000, test=0.979) total time=   0.1s
# [CV 4/5; 10/90] START max_features=15, n_estimators=30..........................
# [CV 4/5; 10/90] END max_features=15, n_estimators=30;, score=(train=1.000, test=0.981) total time=   0.1s
# [CV 5/5; 10/90] START max_features=15, n_estimators=30..........................
# [CV 5/5; 10/90] END max_features=15, n_estimators=30;, score=(train=1.000, test=0.965) total time=   0.1s
# [CV 1/5; 11/90] START max_features=20, n_estimators=10..........................
# [CV 1/5; 11/90] END max_features=20, n_estimators=10;, score=(train=0.998, test=0.959) total time=   0.0s
# [CV 2/5; 11/90] START max_features=20, n_estimators=10..........................
# [CV 2/5; 11/90] END max_features=20, n_estimators=10;, score=(train=0.997, test=0.961) total time=   0.0s
# [CV 3/5; 11/90] START max_features=20, n_estimators=10..........................
# [CV 3/5; 11/90] END max_features=20, n_estimators=10;, score=(train=0.998, test=0.974) total time=   0.0s
# [CV 4/5; 11/90] START max_features=20, n_estimators=10..........................
# [CV 4/5; 11/90] END max_features=20, n_estimators=10;, score=(train=0.998, test=0.970) total time=   0.0s
# [CV 5/5; 11/90] START max_features=20, n_estimators=10..........................
# [CV 5/5; 11/90] END max_features=20, n_estimators=10;, score=(train=0.999, test=0.947) total time=   0.0s
# [CV 1/5; 12/90] START max_features=20, n_estimators=15..........................
# [CV 1/5; 12/90] END max_features=20, n_estimators=15;, score=(train=1.000, test=0.961) total time=   0.3s
# [CV 2/5; 12/90] START max_features=20, n_estimators=15..........................
# [CV 2/5; 12/90] END max_features=20, n_estimators=15;, score=(train=1.000, test=0.969) total time=   0.0s
# [CV 3/5; 12/90] START max_features=20, n_estimators=15..........................
# [CV 3/5; 12/90] END max_features=20, n_estimators=15;, score=(train=1.000, test=0.981) total time=   0.0s
# [CV 4/5; 12/90] START max_features=20, n_estimators=15..........................
# [CV 4/5; 12/90] END max_features=20, n_estimators=15;, score=(train=1.000, test=0.976) total time=   0.0s
# [CV 5/5; 12/90] START max_features=20, n_estimators=15..........................
# [CV 5/5; 12/90] END max_features=20, n_estimators=15;, score=(train=0.999, test=0.962) total time=   0.0s
# [CV 1/5; 13/90] START max_features=20, n_estimators=20..........................
# [CV 1/5; 13/90] END max_features=20, n_estimators=20;, score=(train=1.000, test=0.969) total time=   0.1s
# [CV 2/5; 13/90] START max_features=20, n_estimators=20..........................
# [CV 2/5; 13/90] END max_features=20, n_estimators=20;, score=(train=1.000, test=0.967) total time=   0.1s
# [CV 3/5; 13/90] START max_features=20, n_estimators=20..........................
# [CV 3/5; 13/90] END max_features=20, n_estimators=20;, score=(train=1.000, test=0.973) total time=   0.1s
# [CV 4/5; 13/90] START max_features=20, n_estimators=20..........................
# [CV 4/5; 13/90] END max_features=20, n_estimators=20;, score=(train=1.000, test=0.979) total time=   0.1s
# [CV 5/5; 13/90] START max_features=20, n_estimators=20..........................
# [CV 5/5; 13/90] END max_features=20, n_estimators=20;, score=(train=0.999, test=0.967) total time=   0.1s
# [CV 1/5; 14/90] START max_features=20, n_estimators=25..........................
# [CV 1/5; 14/90] END max_features=20, n_estimators=25;, score=(train=1.000, test=0.963) total time=   0.1s
# [CV 2/5; 14/90] START max_features=20, n_estimators=25..........................
# [CV 2/5; 14/90] END max_features=20, n_estimators=25;, score=(train=1.000, test=0.968) total time=   0.1s
# [CV 3/5; 14/90] START max_features=20, n_estimators=25..........................
# [CV 3/5; 14/90] END max_features=20, n_estimators=25;, score=(train=1.000, test=0.980) total time=   0.1s
# [CV 4/5; 14/90] START max_features=20, n_estimators=25..........................
# [CV 4/5; 14/90] END max_features=20, n_estimators=25;, score=(train=1.000, test=0.980) total time=   0.1s
# [CV 5/5; 14/90] START max_features=20, n_estimators=25..........................
# [CV 5/5; 14/90] END max_features=20, n_estimators=25;, score=(train=1.000, test=0.967) total time=   0.1s
# [CV 1/5; 15/90] START max_features=20, n_estimators=30..........................
# [CV 1/5; 15/90] END max_features=20, n_estimators=30;, score=(train=1.000, test=0.971) total time=   0.1s
# [CV 2/5; 15/90] START max_features=20, n_estimators=30..........................
# [CV 2/5; 15/90] END max_features=20, n_estimators=30;, score=(train=1.000, test=0.972) total time=   0.1s
# [CV 3/5; 15/90] START max_features=20, n_estimators=30..........................
# [CV 3/5; 15/90] END max_features=20, n_estimators=30;, score=(train=1.000, test=0.981) total time=   0.1s
# [CV 4/5; 15/90] START max_features=20, n_estimators=30..........................
# [CV 4/5; 15/90] END max_features=20, n_estimators=30;, score=(train=1.000, test=0.978) total time=   0.1s
# [CV 5/5; 15/90] START max_features=20, n_estimators=30..........................
# [CV 5/5; 15/90] END max_features=20, n_estimators=30;, score=(train=1.000, test=0.968) total time=   0.1s
# [CV 1/5; 16/90] START max_features=25, n_estimators=10..........................
# [CV 1/5; 16/90] END max_features=25, n_estimators=10;, score=(train=0.998, test=0.960) total time=   0.0s
# [CV 2/5; 16/90] START max_features=25, n_estimators=10..........................
# [CV 2/5; 16/90] END max_features=25, n_estimators=10;, score=(train=0.999, test=0.964) total time=   0.0s
# [CV 3/5; 16/90] START max_features=25, n_estimators=10..........................
# [CV 3/5; 16/90] END max_features=25, n_estimators=10;, score=(train=0.999, test=0.979) total time=   0.0s
# [CV 4/5; 16/90] START max_features=25, n_estimators=10..........................
# [CV 4/5; 16/90] END max_features=25, n_estimators=10;, score=(train=0.998, test=0.974) total time=   0.0s
# [CV 5/5; 16/90] START max_features=25, n_estimators=10..........................
# [CV 5/5; 16/90] END max_features=25, n_estimators=10;, score=(train=0.998, test=0.961) total time=   0.0s
# [CV 1/5; 17/90] START max_features=25, n_estimators=15..........................
# [CV 1/5; 17/90] END max_features=25, n_estimators=15;, score=(train=1.000, test=0.959) total time=   0.1s
# [CV 2/5; 17/90] START max_features=25, n_estimators=15..........................
# [CV 2/5; 17/90] END max_features=25, n_estimators=15;, score=(train=0.999, test=0.969) total time=   0.1s
# [CV 3/5; 17/90] START max_features=25, n_estimators=15..........................
# [CV 3/5; 17/90] END max_features=25, n_estimators=15;, score=(train=1.000, test=0.978) total time=   0.1s
# [CV 4/5; 17/90] START max_features=25, n_estimators=15..........................
# [CV 4/5; 17/90] END max_features=25, n_estimators=15;, score=(train=1.000, test=0.972) total time=   0.1s
# [CV 5/5; 17/90] START max_features=25, n_estimators=15..........................
# [CV 5/5; 17/90] END max_features=25, n_estimators=15;, score=(train=1.000, test=0.956) total time=   0.1s
# [CV 1/5; 18/90] START max_features=25, n_estimators=20..........................
# [CV 1/5; 18/90] END max_features=25, n_estimators=20;, score=(train=1.000, test=0.964) total time=   0.1s
# [CV 2/5; 18/90] START max_features=25, n_estimators=20..........................
# [CV 2/5; 18/90] END max_features=25, n_estimators=20;, score=(train=1.000, test=0.974) total time=   0.1s
# [CV 3/5; 18/90] START max_features=25, n_estimators=20..........................
# [CV 3/5; 18/90] END max_features=25, n_estimators=20;, score=(train=1.000, test=0.977) total time=   0.1s
# [CV 4/5; 18/90] START max_features=25, n_estimators=20..........................
# [CV 4/5; 18/90] END max_features=25, n_estimators=20;, score=(train=0.999, test=0.973) total time=   0.1s
# [CV 5/5; 18/90] START max_features=25, n_estimators=20..........................
# [CV 5/5; 18/90] END max_features=25, n_estimators=20;, score=(train=0.999, test=0.966) total time=   0.1s
# [CV 1/5; 19/90] START max_features=25, n_estimators=25..........................
# [CV 1/5; 19/90] END max_features=25, n_estimators=25;, score=(train=1.000, test=0.972) total time=   0.1s
# [CV 2/5; 19/90] START max_features=25, n_estimators=25..........................
# [CV 2/5; 19/90] END max_features=25, n_estimators=25;, score=(train=0.999, test=0.969) total time=   0.1s
# [CV 3/5; 19/90] START max_features=25, n_estimators=25..........................
# [CV 3/5; 19/90] END max_features=25, n_estimators=25;, score=(train=1.000, test=0.976) total time=   0.1s
# [CV 4/5; 19/90] START max_features=25, n_estimators=25..........................
# [CV 4/5; 19/90] END max_features=25, n_estimators=25;, score=(train=1.000, test=0.977) total time=   0.1s
# [CV 5/5; 19/90] START max_features=25, n_estimators=25..........................
# [CV 5/5; 19/90] END max_features=25, n_estimators=25;, score=(train=1.000, test=0.962) total time=   0.1s
# [CV 1/5; 20/90] START max_features=25, n_estimators=30..........................
# [CV 1/5; 20/90] END max_features=25, n_estimators=30;, score=(train=1.000, test=0.964) total time=   0.1s
# [CV 2/5; 20/90] START max_features=25, n_estimators=30..........................
# [CV 2/5; 20/90] END max_features=25, n_estimators=30;, score=(train=1.000, test=0.972) total time=   0.1s
# [CV 3/5; 20/90] START max_features=25, n_estimators=30..........................
# [CV 3/5; 20/90] END max_features=25, n_estimators=30;, score=(train=1.000, test=0.979) total time=   0.1s
# [CV 4/5; 20/90] START max_features=25, n_estimators=30..........................
# [CV 4/5; 20/90] END max_features=25, n_estimators=30;, score=(train=1.000, test=0.972) total time=   0.1s
# [CV 5/5; 20/90] START max_features=25, n_estimators=30..........................
# [CV 5/5; 20/90] END max_features=25, n_estimators=30;, score=(train=1.000, test=0.968) total time=   0.1s
# [CV 1/5; 21/90] START max_features=30, n_estimators=10..........................
# [CV 1/5; 21/90] END max_features=30, n_estimators=10;, score=(train=0.999, test=0.955) total time=   0.0s
# [CV 2/5; 21/90] START max_features=30, n_estimators=10..........................
# [CV 2/5; 21/90] END max_features=30, n_estimators=10;, score=(train=0.999, test=0.961) total time=   0.0s
# [CV 3/5; 21/90] START max_features=30, n_estimators=10..........................
# [CV 3/5; 21/90] END max_features=30, n_estimators=10;, score=(train=0.999, test=0.975) total time=   0.0s
# [CV 4/5; 21/90] START max_features=30, n_estimators=10..........................
# [CV 4/5; 21/90] END max_features=30, n_estimators=10;, score=(train=0.998, test=0.969) total time=   0.0s
# [CV 5/5; 21/90] START max_features=30, n_estimators=10..........................
# [CV 5/5; 21/90] END max_features=30, n_estimators=10;, score=(train=0.998, test=0.959) total time=   0.0s
# [CV 1/5; 22/90] START max_features=30, n_estimators=15..........................
# [CV 1/5; 22/90] END max_features=30, n_estimators=15;, score=(train=0.999, test=0.956) total time=   0.1s
# [CV 2/5; 22/90] START max_features=30, n_estimators=15..........................
# [CV 2/5; 22/90] END max_features=30, n_estimators=15;, score=(train=0.999, test=0.965) total time=   0.1s
# [CV 3/5; 22/90] START max_features=30, n_estimators=15..........................
# [CV 3/5; 22/90] END max_features=30, n_estimators=15;, score=(train=0.999, test=0.975) total time=   0.1s
# [CV 4/5; 22/90] START max_features=30, n_estimators=15..........................
# [CV 4/5; 22/90] END max_features=30, n_estimators=15;, score=(train=1.000, test=0.976) total time=   0.1s
# [CV 5/5; 22/90] START max_features=30, n_estimators=15..........................
# [CV 5/5; 22/90] END max_features=30, n_estimators=15;, score=(train=1.000, test=0.961) total time=   0.1s
# [CV 1/5; 23/90] START max_features=30, n_estimators=20..........................
# [CV 1/5; 23/90] END max_features=30, n_estimators=20;, score=(train=1.000, test=0.959) total time=   0.1s
# [CV 2/5; 23/90] START max_features=30, n_estimators=20..........................
# [CV 2/5; 23/90] END max_features=30, n_estimators=20;, score=(train=1.000, test=0.972) total time=   0.1s
# [CV 3/5; 23/90] START max_features=30, n_estimators=20..........................
# [CV 3/5; 23/90] END max_features=30, n_estimators=20;, score=(train=0.999, test=0.977) total time=   0.1s
# [CV 4/5; 23/90] START max_features=30, n_estimators=20..........................
# [CV 4/5; 23/90] END max_features=30, n_estimators=20;, score=(train=1.000, test=0.978) total time=   0.1s
# [CV 5/5; 23/90] START max_features=30, n_estimators=20..........................
# [CV 5/5; 23/90] END max_features=30, n_estimators=20;, score=(train=0.999, test=0.964) total time=   0.1s
# [CV 1/5; 24/90] START max_features=30, n_estimators=25..........................
# [CV 1/5; 24/90] END max_features=30, n_estimators=25;, score=(train=1.000, test=0.959) total time=   0.1s
# [CV 2/5; 24/90] START max_features=30, n_estimators=25..........................
# [CV 2/5; 24/90] END max_features=30, n_estimators=25;, score=(train=1.000, test=0.974) total time=   0.1s
# [CV 3/5; 24/90] START max_features=30, n_estimators=25..........................
# [CV 3/5; 24/90] END max_features=30, n_estimators=25;, score=(train=1.000, test=0.979) total time=   0.1s
# [CV 4/5; 24/90] START max_features=30, n_estimators=25..........................
# [CV 4/5; 24/90] END max_features=30, n_estimators=25;, score=(train=1.000, test=0.977) total time=   0.1s
# [CV 5/5; 24/90] START max_features=30, n_estimators=25..........................
# [CV 5/5; 24/90] END max_features=30, n_estimators=25;, score=(train=1.000, test=0.962) total time=   0.1s
# [CV 1/5; 25/90] START max_features=30, n_estimators=30..........................
# [CV 1/5; 25/90] END max_features=30, n_estimators=30;, score=(train=1.000, test=0.961) total time=   0.1s
# [CV 2/5; 25/90] START max_features=30, n_estimators=30..........................
# [CV 2/5; 25/90] END max_features=30, n_estimators=30;, score=(train=1.000, test=0.972) total time=   0.2s
# [CV 3/5; 25/90] START max_features=30, n_estimators=30..........................
# [CV 3/5; 25/90] END max_features=30, n_estimators=30;, score=(train=1.000, test=0.978) total time=   0.2s
# [CV 4/5; 25/90] START max_features=30, n_estimators=30..........................
# [CV 4/5; 25/90] END max_features=30, n_estimators=30;, score=(train=1.000, test=0.973) total time=   0.1s
# [CV 5/5; 25/90] START max_features=30, n_estimators=30..........................
# [CV 5/5; 25/90] END max_features=30, n_estimators=30;, score=(train=1.000, test=0.964) total time=   0.2s
# [CV 1/5; 26/90] START max_features=35, n_estimators=10..........................
# [CV 1/5; 26/90] END max_features=35, n_estimators=10;, score=(train=0.998, test=0.956) total time=   0.1s
# [CV 2/5; 26/90] START max_features=35, n_estimators=10..........................
# [CV 2/5; 26/90] END max_features=35, n_estimators=10;, score=(train=0.999, test=0.961) total time=   0.1s
# [CV 3/5; 26/90] START max_features=35, n_estimators=10..........................
# [CV 3/5; 26/90] END max_features=35, n_estimators=10;, score=(train=0.998, test=0.974) total time=   0.1s
# [CV 4/5; 26/90] START max_features=35, n_estimators=10..........................
# [CV 4/5; 26/90] END max_features=35, n_estimators=10;, score=(train=0.998, test=0.966) total time=   0.1s
# [CV 5/5; 26/90] START max_features=35, n_estimators=10..........................
# [CV 5/5; 26/90] END max_features=35, n_estimators=10;, score=(train=0.999, test=0.958) total time=   0.1s
# [CV 1/5; 27/90] START max_features=35, n_estimators=15..........................
# [CV 1/5; 27/90] END max_features=35, n_estimators=15;, score=(train=1.000, test=0.961) total time=   0.1s
# [CV 2/5; 27/90] START max_features=35, n_estimators=15..........................
# [CV 2/5; 27/90] END max_features=35, n_estimators=15;, score=(train=0.999, test=0.965) total time=   0.1s
# [CV 3/5; 27/90] START max_features=35, n_estimators=15..........................
# [CV 3/5; 27/90] END max_features=35, n_estimators=15;, score=(train=0.999, test=0.970) total time=   0.1s
# [CV 4/5; 27/90] START max_features=35, n_estimators=15..........................
# [CV 4/5; 27/90] END max_features=35, n_estimators=15;, score=(train=1.000, test=0.976) total time=   0.1s
# [CV 5/5; 27/90] START max_features=35, n_estimators=15..........................
# [CV 5/5; 27/90] END max_features=35, n_estimators=15;, score=(train=0.999, test=0.962) total time=   0.1s
# [CV 1/5; 28/90] START max_features=35, n_estimators=20..........................
# [CV 1/5; 28/90] END max_features=35, n_estimators=20;, score=(train=1.000, test=0.965) total time=   0.1s
# [CV 2/5; 28/90] START max_features=35, n_estimators=20..........................
# [CV 2/5; 28/90] END max_features=35, n_estimators=20;, score=(train=1.000, test=0.968) total time=   0.1s
# [CV 3/5; 28/90] START max_features=35, n_estimators=20..........................
# [CV 3/5; 28/90] END max_features=35, n_estimators=20;, score=(train=0.999, test=0.975) total time=   0.1s
# [CV 4/5; 28/90] START max_features=35, n_estimators=20..........................
# [CV 4/5; 28/90] END max_features=35, n_estimators=20;, score=(train=0.999, test=0.977) total time=   0.1s
# [CV 5/5; 28/90] START max_features=35, n_estimators=20..........................
# [CV 5/5; 28/90] END max_features=35, n_estimators=20;, score=(train=1.000, test=0.960) total time=   0.1s
# [CV 1/5; 29/90] START max_features=35, n_estimators=25..........................
# [CV 1/5; 29/90] END max_features=35, n_estimators=25;, score=(train=0.999, test=0.963) total time=   0.1s
# [CV 2/5; 29/90] START max_features=35, n_estimators=25..........................
# [CV 2/5; 29/90] END max_features=35, n_estimators=25;, score=(train=1.000, test=0.971) total time=   0.2s
# [CV 3/5; 29/90] START max_features=35, n_estimators=25..........................
# [CV 3/5; 29/90] END max_features=35, n_estimators=25;, score=(train=1.000, test=0.981) total time=   0.1s
# [CV 4/5; 29/90] START max_features=35, n_estimators=25..........................
# [CV 4/5; 29/90] END max_features=35, n_estimators=25;, score=(train=1.000, test=0.980) total time=   0.2s
# [CV 5/5; 29/90] START max_features=35, n_estimators=25..........................
# [CV 5/5; 29/90] END max_features=35, n_estimators=25;, score=(train=1.000, test=0.965) total time=   0.1s
# [CV 1/5; 30/90] START max_features=35, n_estimators=30..........................
# [CV 1/5; 30/90] END max_features=35, n_estimators=30;, score=(train=1.000, test=0.970) total time=   0.2s
# [CV 2/5; 30/90] START max_features=35, n_estimators=30..........................
# [CV 2/5; 30/90] END max_features=35, n_estimators=30;, score=(train=1.000, test=0.965) total time=   0.2s
# [CV 3/5; 30/90] START max_features=35, n_estimators=30..........................
# [CV 3/5; 30/90] END max_features=35, n_estimators=30;, score=(train=1.000, test=0.977) total time=   0.2s
# [CV 4/5; 30/90] START max_features=35, n_estimators=30..........................
# [CV 4/5; 30/90] END max_features=35, n_estimators=30;, score=(train=1.000, test=0.976) total time=   0.2s
# [CV 5/5; 30/90] START max_features=35, n_estimators=30..........................
# [CV 5/5; 30/90] END max_features=35, n_estimators=30;, score=(train=1.000, test=0.961) total time=   0.2s
# [CV 1/5; 31/90] START max_features=40, n_estimators=10..........................
# [CV 1/5; 31/90] END max_features=40, n_estimators=10;, score=(train=0.997, test=0.957) total time=   0.1s
# [CV 2/5; 31/90] START max_features=40, n_estimators=10..........................
# [CV 2/5; 31/90] END max_features=40, n_estimators=10;, score=(train=0.998, test=0.959) total time=   0.1s
# [CV 3/5; 31/90] START max_features=40, n_estimators=10..........................
# [CV 3/5; 31/90] END max_features=40, n_estimators=10;, score=(train=0.998, test=0.965) total time=   0.1s
# [CV 4/5; 31/90] START max_features=40, n_estimators=10..........................
# [CV 4/5; 31/90] END max_features=40, n_estimators=10;, score=(train=0.999, test=0.971) total time=   0.1s
# [CV 5/5; 31/90] START max_features=40, n_estimators=10..........................
# [CV 5/5; 31/90] END max_features=40, n_estimators=10;, score=(train=0.998, test=0.955) total time=   0.1s
# [CV 1/5; 32/90] START max_features=40, n_estimators=15..........................
# [CV 1/5; 32/90] END max_features=40, n_estimators=15;, score=(train=1.000, test=0.951) total time=   0.1s
# [CV 2/5; 32/90] START max_features=40, n_estimators=15..........................
# [CV 2/5; 32/90] END max_features=40, n_estimators=15;, score=(train=1.000, test=0.958) total time=   0.1s
# [CV 3/5; 32/90] START max_features=40, n_estimators=15..........................
# [CV 3/5; 32/90] END max_features=40, n_estimators=15;, score=(train=1.000, test=0.974) total time=   0.1s
# [CV 4/5; 32/90] START max_features=40, n_estimators=15..........................
# [CV 4/5; 32/90] END max_features=40, n_estimators=15;, score=(train=0.999, test=0.976) total time=   0.1s
# [CV 5/5; 32/90] START max_features=40, n_estimators=15..........................
# [CV 5/5; 32/90] END max_features=40, n_estimators=15;, score=(train=0.999, test=0.961) total time=   0.1s
# [CV 1/5; 33/90] START max_features=40, n_estimators=20..........................
# [CV 1/5; 33/90] END max_features=40, n_estimators=20;, score=(train=0.999, test=0.968) total time=   0.1s
# [CV 2/5; 33/90] START max_features=40, n_estimators=20..........................
# [CV 2/5; 33/90] END max_features=40, n_estimators=20;, score=(train=1.000, test=0.972) total time=   0.1s
# [CV 3/5; 33/90] START max_features=40, n_estimators=20..........................
# [CV 3/5; 33/90] END max_features=40, n_estimators=20;, score=(train=0.999, test=0.968) total time=   0.1s
# [CV 4/5; 33/90] START max_features=40, n_estimators=20..........................
# [CV 4/5; 33/90] END max_features=40, n_estimators=20;, score=(train=1.000, test=0.977) total time=   0.1s
# [CV 5/5; 33/90] START max_features=40, n_estimators=20..........................
# [CV 5/5; 33/90] END max_features=40, n_estimators=20;, score=(train=1.000, test=0.959) total time=   0.1s
# [CV 1/5; 34/90] START max_features=40, n_estimators=25..........................
# [CV 1/5; 34/90] END max_features=40, n_estimators=25;, score=(train=1.000, test=0.962) total time=   0.2s
# [CV 2/5; 34/90] START max_features=40, n_estimators=25..........................
# [CV 2/5; 34/90] END max_features=40, n_estimators=25;, score=(train=1.000, test=0.957) total time=   0.2s
# [CV 3/5; 34/90] START max_features=40, n_estimators=25..........................
# [CV 3/5; 34/90] END max_features=40, n_estimators=25;, score=(train=1.000, test=0.972) total time=   0.2s
# [CV 4/5; 34/90] START max_features=40, n_estimators=25..........................
# [CV 4/5; 34/90] END max_features=40, n_estimators=25;, score=(train=1.000, test=0.973) total time=   0.2s
# [CV 5/5; 34/90] START max_features=40, n_estimators=25..........................
# [CV 5/5; 34/90] END max_features=40, n_estimators=25;, score=(train=1.000, test=0.955) total time=   0.2s
# [CV 1/5; 35/90] START max_features=40, n_estimators=30..........................
# [CV 1/5; 35/90] END max_features=40, n_estimators=30;, score=(train=1.000, test=0.962) total time=   0.2s
# [CV 2/5; 35/90] START max_features=40, n_estimators=30..........................
# [CV 2/5; 35/90] END max_features=40, n_estimators=30;, score=(train=1.000, test=0.966) total time=   0.2s
# [CV 3/5; 35/90] START max_features=40, n_estimators=30..........................
# [CV 3/5; 35/90] END max_features=40, n_estimators=30;, score=(train=1.000, test=0.973) total time=   0.2s
# [CV 4/5; 35/90] START max_features=40, n_estimators=30..........................
# [CV 4/5; 35/90] END max_features=40, n_estimators=30;, score=(train=1.000, test=0.976) total time=   0.2s
# [CV 5/5; 35/90] START max_features=40, n_estimators=30..........................
# [CV 5/5; 35/90] END max_features=40, n_estimators=30;, score=(train=1.000, test=0.957) total time=   0.2s
# [CV 1/5; 36/90] START max_features=45, n_estimators=10..........................
# [CV 1/5; 36/90] END max_features=45, n_estimators=10;, score=(train=0.998, test=0.956) total time=   0.1s
# [CV 2/5; 36/90] START max_features=45, n_estimators=10..........................
# [CV 2/5; 36/90] END max_features=45, n_estimators=10;, score=(train=0.998, test=0.962) total time=   0.1s
# [CV 3/5; 36/90] START max_features=45, n_estimators=10..........................
# [CV 3/5; 36/90] END max_features=45, n_estimators=10;, score=(train=0.998, test=0.973) total time=   0.1s
# [CV 4/5; 36/90] START max_features=45, n_estimators=10..........................
# [CV 4/5; 36/90] END max_features=45, n_estimators=10;, score=(train=0.998, test=0.968) total time=   0.1s
# [CV 5/5; 36/90] START max_features=45, n_estimators=10..........................
# [CV 5/5; 36/90] END max_features=45, n_estimators=10;, score=(train=0.998, test=0.962) total time=   0.1s
# [CV 1/5; 37/90] START max_features=45, n_estimators=15..........................
# [CV 1/5; 37/90] END max_features=45, n_estimators=15;, score=(train=0.999, test=0.949) total time=   0.1s
# [CV 2/5; 37/90] START max_features=45, n_estimators=15..........................
# [CV 2/5; 37/90] END max_features=45, n_estimators=15;, score=(train=0.999, test=0.960) total time=   0.1s
# [CV 3/5; 37/90] START max_features=45, n_estimators=15..........................
# [CV 3/5; 37/90] END max_features=45, n_estimators=15;, score=(train=1.000, test=0.971) total time=   0.1s
# [CV 4/5; 37/90] START max_features=45, n_estimators=15..........................
# [CV 4/5; 37/90] END max_features=45, n_estimators=15;, score=(train=0.999, test=0.974) total time=   0.1s
# [CV 5/5; 37/90] START max_features=45, n_estimators=15..........................
# [CV 5/5; 37/90] END max_features=45, n_estimators=15;, score=(train=0.999, test=0.960) total time=   0.1s
# [CV 1/5; 38/90] START max_features=45, n_estimators=20..........................
# [CV 1/5; 38/90] END max_features=45, n_estimators=20;, score=(train=1.000, test=0.955) total time=   0.2s
# [CV 2/5; 38/90] START max_features=45, n_estimators=20..........................
# [CV 2/5; 38/90] END max_features=45, n_estimators=20;, score=(train=1.000, test=0.962) total time=   0.2s
# [CV 3/5; 38/90] START max_features=45, n_estimators=20..........................
# [CV 3/5; 38/90] END max_features=45, n_estimators=20;, score=(train=0.999, test=0.976) total time=   0.2s
# [CV 4/5; 38/90] START max_features=45, n_estimators=20..........................
# [CV 4/5; 38/90] END max_features=45, n_estimators=20;, score=(train=1.000, test=0.972) total time=   0.1s
# [CV 5/5; 38/90] START max_features=45, n_estimators=20..........................
# [CV 5/5; 38/90] END max_features=45, n_estimators=20;, score=(train=1.000, test=0.959) total time=   0.1s
# [CV 1/5; 39/90] START max_features=45, n_estimators=25..........................
# [CV 1/5; 39/90] END max_features=45, n_estimators=25;, score=(train=1.000, test=0.958) total time=   0.2s
# [CV 2/5; 39/90] START max_features=45, n_estimators=25..........................
# [CV 2/5; 39/90] END max_features=45, n_estimators=25;, score=(train=0.999, test=0.965) total time=   0.2s
# [CV 3/5; 39/90] START max_features=45, n_estimators=25..........................
# [CV 3/5; 39/90] END max_features=45, n_estimators=25;, score=(train=1.000, test=0.979) total time=   0.2s
# [CV 4/5; 39/90] START max_features=45, n_estimators=25..........................
# [CV 4/5; 39/90] END max_features=45, n_estimators=25;, score=(train=1.000, test=0.973) total time=   0.2s
# [CV 5/5; 39/90] START max_features=45, n_estimators=25..........................
# [CV 5/5; 39/90] END max_features=45, n_estimators=25;, score=(train=1.000, test=0.954) total time=   0.2s
# [CV 1/5; 40/90] START max_features=45, n_estimators=30..........................
# [CV 1/5; 40/90] END max_features=45, n_estimators=30;, score=(train=1.000, test=0.957) total time=   0.2s
# [CV 2/5; 40/90] START max_features=45, n_estimators=30..........................
# [CV 2/5; 40/90] END max_features=45, n_estimators=30;, score=(train=1.000, test=0.961) total time=   0.2s
# [CV 3/5; 40/90] START max_features=45, n_estimators=30..........................
# [CV 3/5; 40/90] END max_features=45, n_estimators=30;, score=(train=1.000, test=0.973) total time=   0.2s
# [CV 4/5; 40/90] START max_features=45, n_estimators=30..........................
# [CV 4/5; 40/90] END max_features=45, n_estimators=30;, score=(train=1.000, test=0.975) total time=   0.2s
# [CV 5/5; 40/90] START max_features=45, n_estimators=30..........................
# [CV 5/5; 40/90] END max_features=45, n_estimators=30;, score=(train=1.000, test=0.957) total time=   0.2s
# [CV 1/5; 41/90] START max_features=50, n_estimators=10..........................
# [CV 1/5; 41/90] END max_features=50, n_estimators=10;, score=(train=0.997, test=0.944) total time=   0.1s
# [CV 2/5; 41/90] START max_features=50, n_estimators=10..........................
# [CV 2/5; 41/90] END max_features=50, n_estimators=10;, score=(train=0.997, test=0.955) total time=   0.1s
# [CV 3/5; 41/90] START max_features=50, n_estimators=10..........................
# [CV 3/5; 41/90] END max_features=50, n_estimators=10;, score=(train=0.998, test=0.973) total time=   0.1s
# [CV 4/5; 41/90] START max_features=50, n_estimators=10..........................
# [CV 4/5; 41/90] END max_features=50, n_estimators=10;, score=(train=0.998, test=0.969) total time=   0.1s
# [CV 5/5; 41/90] START max_features=50, n_estimators=10..........................
# [CV 5/5; 41/90] END max_features=50, n_estimators=10;, score=(train=0.996, test=0.948) total time=   0.1s
# [CV 1/5; 42/90] START max_features=50, n_estimators=15..........................
# [CV 1/5; 42/90] END max_features=50, n_estimators=15;, score=(train=0.999, test=0.951) total time=   0.1s
# [CV 2/5; 42/90] START max_features=50, n_estimators=15..........................
# [CV 2/5; 42/90] END max_features=50, n_estimators=15;, score=(train=1.000, test=0.959) total time=   0.1s
# [CV 3/5; 42/90] START max_features=50, n_estimators=15..........................
# [CV 3/5; 42/90] END max_features=50, n_estimators=15;, score=(train=0.999, test=0.971) total time=   0.1s
# [CV 4/5; 42/90] START max_features=50, n_estimators=15..........................
# [CV 4/5; 42/90] END max_features=50, n_estimators=15;, score=(train=0.999, test=0.968) total time=   0.1s
# [CV 5/5; 42/90] START max_features=50, n_estimators=15..........................
# [CV 5/5; 42/90] END max_features=50, n_estimators=15;, score=(train=1.000, test=0.955) total time=   0.2s
# [CV 1/5; 43/90] START max_features=50, n_estimators=20..........................
# [CV 1/5; 43/90] END max_features=50, n_estimators=20;, score=(train=1.000, test=0.951) total time=   0.2s
# [CV 2/5; 43/90] START max_features=50, n_estimators=20..........................
# [CV 2/5; 43/90] END max_features=50, n_estimators=20;, score=(train=0.999, test=0.961) total time=   0.2s
# [CV 3/5; 43/90] START max_features=50, n_estimators=20..........................
# [CV 3/5; 43/90] END max_features=50, n_estimators=20;, score=(train=0.999, test=0.972) total time=   0.2s
# [CV 4/5; 43/90] START max_features=50, n_estimators=20..........................
# [CV 4/5; 43/90] END max_features=50, n_estimators=20;, score=(train=0.999, test=0.971) total time=   0.2s
# [CV 5/5; 43/90] START max_features=50, n_estimators=20..........................
# [CV 5/5; 43/90] END max_features=50, n_estimators=20;, score=(train=1.000, test=0.956) total time=   0.2s
# [CV 1/5; 44/90] START max_features=50, n_estimators=25..........................
# [CV 1/5; 44/90] END max_features=50, n_estimators=25;, score=(train=1.000, test=0.966) total time=   0.2s
# [CV 2/5; 44/90] START max_features=50, n_estimators=25..........................
# [CV 2/5; 44/90] END max_features=50, n_estimators=25;, score=(train=1.000, test=0.965) total time=   0.2s
# [CV 3/5; 44/90] START max_features=50, n_estimators=25..........................
# [CV 3/5; 44/90] END max_features=50, n_estimators=25;, score=(train=1.000, test=0.976) total time=   0.2s
# [CV 4/5; 44/90] START max_features=50, n_estimators=25..........................
# [CV 4/5; 44/90] END max_features=50, n_estimators=25;, score=(train=0.999, test=0.971) total time=   0.2s
# [CV 5/5; 44/90] START max_features=50, n_estimators=25..........................
# [CV 5/5; 44/90] END max_features=50, n_estimators=25;, score=(train=1.000, test=0.956) total time=   0.2s
# [CV 1/5; 45/90] START max_features=50, n_estimators=30..........................
# [CV 1/5; 45/90] END max_features=50, n_estimators=30;, score=(train=1.000, test=0.957) total time=   0.2s
# [CV 2/5; 45/90] START max_features=50, n_estimators=30..........................
# [CV 2/5; 45/90] END max_features=50, n_estimators=30;, score=(train=1.000, test=0.962) total time=   0.2s
# [CV 3/5; 45/90] START max_features=50, n_estimators=30..........................
# [CV 3/5; 45/90] END max_features=50, n_estimators=30;, score=(train=1.000, test=0.974) total time=   0.2s
# [CV 4/5; 45/90] START max_features=50, n_estimators=30..........................
# [CV 4/5; 45/90] END max_features=50, n_estimators=30;, score=(train=1.000, test=0.970) total time=   0.2s
# [CV 5/5; 45/90] START max_features=50, n_estimators=30..........................
# [CV 5/5; 45/90] END max_features=50, n_estimators=30;, score=(train=1.000, test=0.958) total time=   0.2s
# [CV 1/5; 46/90] START bootstrap=False, max_features=10, n_estimators=10.........
# [CV 1/5; 46/90] END bootstrap=False, max_features=10, n_estimators=10;, score=(train=1.000, test=0.969) total time=   0.0s
# [CV 2/5; 46/90] START bootstrap=False, max_features=10, n_estimators=10.........
# [CV 2/5; 46/90] END bootstrap=False, max_features=10, n_estimators=10;, score=(train=1.000, test=0.968) total time=   0.0s
# [CV 3/5; 46/90] START bootstrap=False, max_features=10, n_estimators=10.........
# [CV 3/5; 46/90] END bootstrap=False, max_features=10, n_estimators=10;, score=(train=1.000, test=0.979) total time=   0.0s
# [CV 4/5; 46/90] START bootstrap=False, max_features=10, n_estimators=10.........
# [CV 4/5; 46/90] END bootstrap=False, max_features=10, n_estimators=10;, score=(train=1.000, test=0.986) total time=   0.0s
# [CV 5/5; 46/90] START bootstrap=False, max_features=10, n_estimators=10.........
# [CV 5/5; 46/90] END bootstrap=False, max_features=10, n_estimators=10;, score=(train=1.000, test=0.972) total time=   0.0s
# [CV 1/5; 47/90] START bootstrap=False, max_features=10, n_estimators=15.........
# [CV 1/5; 47/90] END bootstrap=False, max_features=10, n_estimators=15;, score=(train=1.000, test=0.973) total time=   0.0s
# [CV 2/5; 47/90] START bootstrap=False, max_features=10, n_estimators=15.........
# [CV 2/5; 47/90] END bootstrap=False, max_features=10, n_estimators=15;, score=(train=1.000, test=0.979) total time=   0.0s
# [CV 3/5; 47/90] START bootstrap=False, max_features=10, n_estimators=15.........
# [CV 3/5; 47/90] END bootstrap=False, max_features=10, n_estimators=15;, score=(train=1.000, test=0.986) total time=   0.0s
# [CV 4/5; 47/90] START bootstrap=False, max_features=10, n_estimators=15.........
# [CV 4/5; 47/90] END bootstrap=False, max_features=10, n_estimators=15;, score=(train=1.000, test=0.989) total time=   0.0s
# [CV 5/5; 47/90] START bootstrap=False, max_features=10, n_estimators=15.........
# [CV 5/5; 47/90] END bootstrap=False, max_features=10, n_estimators=15;, score=(train=1.000, test=0.979) total time=   0.0s
# [CV 1/5; 48/90] START bootstrap=False, max_features=10, n_estimators=20.........
# [CV 1/5; 48/90] END bootstrap=False, max_features=10, n_estimators=20;, score=(train=1.000, test=0.975) total time=   0.1s
# [CV 2/5; 48/90] START bootstrap=False, max_features=10, n_estimators=20.........
# [CV 2/5; 48/90] END bootstrap=False, max_features=10, n_estimators=20;, score=(train=1.000, test=0.973) total time=   0.1s
# [CV 3/5; 48/90] START bootstrap=False, max_features=10, n_estimators=20.........
# [CV 3/5; 48/90] END bootstrap=False, max_features=10, n_estimators=20;, score=(train=1.000, test=0.985) total time=   0.0s
# [CV 4/5; 48/90] START bootstrap=False, max_features=10, n_estimators=20.........
# [CV 4/5; 48/90] END bootstrap=False, max_features=10, n_estimators=20;, score=(train=1.000, test=0.985) total time=   0.1s
# [CV 5/5; 48/90] START bootstrap=False, max_features=10, n_estimators=20.........
# [CV 5/5; 48/90] END bootstrap=False, max_features=10, n_estimators=20;, score=(train=1.000, test=0.977) total time=   0.1s
# [CV 1/5; 49/90] START bootstrap=False, max_features=10, n_estimators=25.........
# [CV 1/5; 49/90] END bootstrap=False, max_features=10, n_estimators=25;, score=(train=1.000, test=0.976) total time=   0.1s
# [CV 2/5; 49/90] START bootstrap=False, max_features=10, n_estimators=25.........
# [CV 2/5; 49/90] END bootstrap=False, max_features=10, n_estimators=25;, score=(train=1.000, test=0.980) total time=   0.1s
# [CV 3/5; 49/90] START bootstrap=False, max_features=10, n_estimators=25.........
# [CV 3/5; 49/90] END bootstrap=False, max_features=10, n_estimators=25;, score=(train=1.000, test=0.983) total time=   0.1s
# [CV 4/5; 49/90] START bootstrap=False, max_features=10, n_estimators=25.........
# [CV 4/5; 49/90] END bootstrap=False, max_features=10, n_estimators=25;, score=(train=1.000, test=0.985) total time=   0.1s
# [CV 5/5; 49/90] START bootstrap=False, max_features=10, n_estimators=25.........
# [CV 5/5; 49/90] END bootstrap=False, max_features=10, n_estimators=25;, score=(train=1.000, test=0.974) total time=   0.1s
# [CV 1/5; 50/90] START bootstrap=False, max_features=10, n_estimators=30.........
# [CV 1/5; 50/90] END bootstrap=False, max_features=10, n_estimators=30;, score=(train=1.000, test=0.976) total time=   0.1s
# [CV 2/5; 50/90] START bootstrap=False, max_features=10, n_estimators=30.........
# [CV 2/5; 50/90] END bootstrap=False, max_features=10, n_estimators=30;, score=(train=1.000, test=0.977) total time=   0.1s
# [CV 3/5; 50/90] START bootstrap=False, max_features=10, n_estimators=30.........
# [CV 3/5; 50/90] END bootstrap=False, max_features=10, n_estimators=30;, score=(train=1.000, test=0.983) total time=   0.1s
# [CV 4/5; 50/90] START bootstrap=False, max_features=10, n_estimators=30.........
# [CV 4/5; 50/90] END bootstrap=False, max_features=10, n_estimators=30;, score=(train=1.000, test=0.984) total time=   0.1s
# [CV 5/5; 50/90] START bootstrap=False, max_features=10, n_estimators=30.........
# [CV 5/5; 50/90] END bootstrap=False, max_features=10, n_estimators=30;, score=(train=1.000, test=0.972) total time=   0.1s
# [CV 1/5; 51/90] START bootstrap=False, max_features=15, n_estimators=10.........
# [CV 1/5; 51/90] END bootstrap=False, max_features=15, n_estimators=10;, score=(train=1.000, test=0.964) total time=   0.0s
# [CV 2/5; 51/90] START bootstrap=False, max_features=15, n_estimators=10.........
# [CV 2/5; 51/90] END bootstrap=False, max_features=15, n_estimators=10;, score=(train=1.000, test=0.974) total time=   0.0s
# [CV 3/5; 51/90] START bootstrap=False, max_features=15, n_estimators=10.........
# [CV 3/5; 51/90] END bootstrap=False, max_features=15, n_estimators=10;, score=(train=1.000, test=0.976) total time=   0.0s
# [CV 4/5; 51/90] START bootstrap=False, max_features=15, n_estimators=10.........
# ...
# [CV 4/5; 75/90] START bootstrap=False, max_features=35, n_estimators=30.........
# [CV 4/5; 75/90] END bootstrap=False, max_features=35, n_estimators=30;, score=(train=1.000, test=0.981) total time=   0.3s
# [CV 5/5; 75/90] START bootstrap=False, max_features=35, n_estimators=30.........
# [CV 5/5; 75/90] END bootstrap=False, max_features=35, n_estimators=30;, score=(train=1.000, test=0.971) total time=   0.3s
# [CV 1/5; 76/90] START bootstrap=False, max_features=40, n_estimators=10.........
# [CV 1/5; 76/90] END bootstrap=False, max_features=40, n_estimators=10;, score=(train=1.000, test=0.952) total time=   0.2s
# [CV 2/5; 76/90] START bootstrap=False, max_features=40, n_estimators=10.........
# [CV 2/5; 76/90] END bootstrap=False, max_features=40, n_estimators=10;, score=(train=1.000, test=0.960) total time=   0.2s
# [CV 3/5; 76/90] START bootstrap=False, max_features=40, n_estimators=10.........
# [CV 3/5; 76/90] END bootstrap=False, max_features=40, n_estimators=10;, score=(train=1.000, test=0.976) total time=   0.1s
# [CV 4/5; 76/90] START bootstrap=False, max_features=40, n_estimators=10.........
# [CV 4/5; 76/90] END bootstrap=False, max_features=40, n_estimators=10;, score=(train=1.000, test=0.971) total time=   0.1s
# [CV 5/5; 76/90] START bootstrap=False, max_features=40, n_estimators=10.........
# [CV 5/5; 76/90] END bootstrap=False, max_features=40, n_estimators=10;, score=(train=1.000, test=0.955) total time=   0.1s
# [CV 1/5; 77/90] START bootstrap=False, max_features=40, n_estimators=15.........
# [CV 1/5; 77/90] END bootstrap=False, max_features=40, n_estimators=15;, score=(train=1.000, test=0.965) total time=   0.2s
# [CV 2/5; 77/90] START bootstrap=False, max_features=40, n_estimators=15.........
# [CV 2/5; 77/90] END bootstrap=False, max_features=40, n_estimators=15;, score=(train=1.000, test=0.969) total time=   0.2s
# [CV 3/5; 77/90] START bootstrap=False, max_features=40, n_estimators=15.........
# [CV 3/5; 77/90] END bootstrap=False, max_features=40, n_estimators=15;, score=(train=1.000, test=0.975) total time=   0.2s
# [CV 4/5; 77/90] START bootstrap=False, max_features=40, n_estimators=15.........
# [CV 4/5; 77/90] END bootstrap=False, max_features=40, n_estimators=15;, score=(train=1.000, test=0.974) total time=   0.2s
# [CV 5/5; 77/90] START bootstrap=False, max_features=40, n_estimators=15.........
# [CV 5/5; 77/90] END bootstrap=False, max_features=40, n_estimators=15;, score=(train=1.000, test=0.963) total time=   0.2s
# [CV 1/5; 78/90] START bootstrap=False, max_features=40, n_estimators=20.........
# [CV 1/5; 78/90] END bootstrap=False, max_features=40, n_estimators=20;, score=(train=1.000, test=0.959) total time=   0.2s
# [CV 2/5; 78/90] START bootstrap=False, max_features=40, n_estimators=20.........
# [CV 2/5; 78/90] END bootstrap=False, max_features=40, n_estimators=20;, score=(train=1.000, test=0.967) total time=   0.2s
# [CV 3/5; 78/90] START bootstrap=False, max_features=40, n_estimators=20.........
# [CV 3/5; 78/90] END bootstrap=False, max_features=40, n_estimators=20;, score=(train=1.000, test=0.975) total time=   0.2s
# [CV 4/5; 78/90] START bootstrap=False, max_features=40, n_estimators=20.........
# [CV 4/5; 78/90] END bootstrap=False, max_features=40, n_estimators=20;, score=(train=1.000, test=0.978) total time=   0.2s
# [CV 5/5; 78/90] START bootstrap=False, max_features=40, n_estimators=20.........
# [CV 5/5; 78/90] END bootstrap=False, max_features=40, n_estimators=20;, score=(train=1.000, test=0.960) total time=   0.2s
# [CV 1/5; 79/90] START bootstrap=False, max_features=40, n_estimators=25.........
# [CV 1/5; 79/90] END bootstrap=False, max_features=40, n_estimators=25;, score=(train=1.000, test=0.966) total time=   0.3s
# [CV 2/5; 79/90] START bootstrap=False, max_features=40, n_estimators=25.........
# [CV 2/5; 79/90] END bootstrap=False, max_features=40, n_estimators=25;, score=(train=1.000, test=0.970) total time=   0.3s
# [CV 3/5; 79/90] START bootstrap=False, max_features=40, n_estimators=25.........
# [CV 3/5; 79/90] END bootstrap=False, max_features=40, n_estimators=25;, score=(train=1.000, test=0.972) total time=   0.3s
# [CV 4/5; 79/90] START bootstrap=False, max_features=40, n_estimators=25.........
# [CV 4/5; 79/90] END bootstrap=False, max_features=40, n_estimators=25;, score=(train=1.000, test=0.980) total time=   0.3s
# [CV 5/5; 79/90] START bootstrap=False, max_features=40, n_estimators=25.........
# [CV 5/5; 79/90] END bootstrap=False, max_features=40, n_estimators=25;, score=(train=1.000, test=0.967) total time=   0.3s
# [CV 1/5; 80/90] START bootstrap=False, max_features=40, n_estimators=30.........
# [CV 1/5; 80/90] END bootstrap=False, max_features=40, n_estimators=30;, score=(train=1.000, test=0.958) total time=   0.3s
# [CV 2/5; 80/90] START bootstrap=False, max_features=40, n_estimators=30.........
# [CV 2/5; 80/90] END bootstrap=False, max_features=40, n_estimators=30;, score=(train=1.000, test=0.963) total time=   0.3s
# [CV 3/5; 80/90] START bootstrap=False, max_features=40, n_estimators=30.........
# [CV 3/5; 80/90] END bootstrap=False, max_features=40, n_estimators=30;, score=(train=1.000, test=0.976) total time=   0.3s
# [CV 4/5; 80/90] START bootstrap=False, max_features=40, n_estimators=30.........
# [CV 4/5; 80/90] END bootstrap=False, max_features=40, n_estimators=30;, score=(train=1.000, test=0.977) total time=   0.3s
# [CV 5/5; 80/90] START bootstrap=False, max_features=40, n_estimators=30.........
# [CV 5/5; 80/90] END bootstrap=False, max_features=40, n_estimators=30;, score=(train=1.000, test=0.967) total time=   0.3s
# [CV 1/5; 81/90] START bootstrap=False, max_features=45, n_estimators=10.........
# [CV 1/5; 81/90] END bootstrap=False, max_features=45, n_estimators=10;, score=(train=1.000, test=0.946) total time=   0.2s
# [CV 2/5; 81/90] START bootstrap=False, max_features=45, n_estimators=10.........
# [CV 2/5; 81/90] END bootstrap=False, max_features=45, n_estimators=10;, score=(train=1.000, test=0.961) total time=   0.2s
# [CV 3/5; 81/90] START bootstrap=False, max_features=45, n_estimators=10.........
# [CV 3/5; 81/90] END bootstrap=False, max_features=45, n_estimators=10;, score=(train=1.000, test=0.966) total time=   0.2s
# [CV 4/5; 81/90] START bootstrap=False, max_features=45, n_estimators=10.........
# [CV 4/5; 81/90] END bootstrap=False, max_features=45, n_estimators=10;, score=(train=1.000, test=0.973) total time=   0.2s
# [CV 5/5; 81/90] START bootstrap=False, max_features=45, n_estimators=10.........
# [CV 5/5; 81/90] END bootstrap=False, max_features=45, n_estimators=10;, score=(train=1.000, test=0.951) total time=   0.2s
# [CV 1/5; 82/90] START bootstrap=False, max_features=45, n_estimators=15.........
# [CV 1/5; 82/90] END bootstrap=False, max_features=45, n_estimators=15;, score=(train=1.000, test=0.950) total time=   0.2s
# [CV 2/5; 82/90] START bootstrap=False, max_features=45, n_estimators=15.........
# [CV 2/5; 82/90] END bootstrap=False, max_features=45, n_estimators=15;, score=(train=1.000, test=0.964) total time=   0.3s
# [CV 3/5; 82/90] START bootstrap=False, max_features=45, n_estimators=15.........
# [CV 3/5; 82/90] END bootstrap=False, max_features=45, n_estimators=15;, score=(train=1.000, test=0.969) total time=   0.2s
# [CV 4/5; 82/90] START bootstrap=False, max_features=45, n_estimators=15.........
# [CV 4/5; 82/90] END bootstrap=False, max_features=45, n_estimators=15;, score=(train=1.000, test=0.976) total time=   0.2s
# [CV 5/5; 82/90] START bootstrap=False, max_features=45, n_estimators=15.........
# [CV 5/5; 82/90] END bootstrap=False, max_features=45, n_estimators=15;, score=(train=1.000, test=0.968) total time=   0.2s
# [CV 1/5; 83/90] START bootstrap=False, max_features=45, n_estimators=20.........
# [CV 1/5; 83/90] END bootstrap=False, max_features=45, n_estimators=20;, score=(train=1.000, test=0.953) total time=   0.3s
# [CV 2/5; 83/90] START bootstrap=False, max_features=45, n_estimators=20.........
# [CV 2/5; 83/90] END bootstrap=False, max_features=45, n_estimators=20;, score=(train=1.000, test=0.962) total time=   0.3s
# [CV 3/5; 83/90] START bootstrap=False, max_features=45, n_estimators=20.........
# [CV 3/5; 83/90] END bootstrap=False, max_features=45, n_estimators=20;, score=(train=1.000, test=0.966) total time=   0.3s
# [CV 4/5; 83/90] START bootstrap=False, max_features=45, n_estimators=20.........
# [CV 4/5; 83/90] END bootstrap=False, max_features=45, n_estimators=20;, score=(train=1.000, test=0.973) total time=   0.3s
# [CV 5/5; 83/90] START bootstrap=False, max_features=45, n_estimators=20.........
# [CV 5/5; 83/90] END bootstrap=False, max_features=45, n_estimators=20;, score=(train=1.000, test=0.963) total time=   0.3s
# [CV 1/5; 84/90] START bootstrap=False, max_features=45, n_estimators=25.........
# [CV 1/5; 84/90] END bootstrap=False, max_features=45, n_estimators=25;, score=(train=1.000, test=0.950) total time=   0.3s
# [CV 2/5; 84/90] START bootstrap=False, max_features=45, n_estimators=25.........
# [CV 2/5; 84/90] END bootstrap=False, max_features=45, n_estimators=25;, score=(train=1.000, test=0.968) total time=   0.3s
# [CV 3/5; 84/90] START bootstrap=False, max_features=45, n_estimators=25.........
# [CV 3/5; 84/90] END bootstrap=False, max_features=45, n_estimators=25;, score=(train=1.000, test=0.976) total time=   0.3s
# [CV 4/5; 84/90] START bootstrap=False, max_features=45, n_estimators=25.........
# [CV 4/5; 84/90] END bootstrap=False, max_features=45, n_estimators=25;, score=(train=1.000, test=0.973) total time=   0.3s
# [CV 5/5; 84/90] START bootstrap=False, max_features=45, n_estimators=25.........
# [CV 5/5; 84/90] END bootstrap=False, max_features=45, n_estimators=25;, score=(train=1.000, test=0.951) total time=   0.3s
# [CV 1/5; 85/90] START bootstrap=False, max_features=45, n_estimators=30.........
# [CV 1/5; 85/90] END bootstrap=False, max_features=45, n_estimators=30;, score=(train=1.000, test=0.950) total time=   0.3s
# [CV 2/5; 85/90] START bootstrap=False, max_features=45, n_estimators=30.........
# [CV 2/5; 85/90] END bootstrap=False, max_features=45, n_estimators=30;, score=(train=1.000, test=0.962) total time=   0.4s
# [CV 3/5; 85/90] START bootstrap=False, max_features=45, n_estimators=30.........
# [CV 3/5; 85/90] END bootstrap=False, max_features=45, n_estimators=30;, score=(train=1.000, test=0.969) total time=   0.3s
# [CV 4/5; 85/90] START bootstrap=False, max_features=45, n_estimators=30.........
# [CV 4/5; 85/90] END bootstrap=False, max_features=45, n_estimators=30;, score=(train=1.000, test=0.974) total time=   0.3s
# [CV 5/5; 85/90] START bootstrap=False, max_features=45, n_estimators=30.........
# [CV 5/5; 85/90] END bootstrap=False, max_features=45, n_estimators=30;, score=(train=1.000, test=0.955) total time=   0.4s
# [CV 1/5; 86/90] START bootstrap=False, max_features=50, n_estimators=10.........
# [CV 1/5; 86/90] END bootstrap=False, max_features=50, n_estimators=10;, score=(train=1.000, test=0.932) total time=   0.2s
# [CV 2/5; 86/90] START bootstrap=False, max_features=50, n_estimators=10.........
# [CV 2/5; 86/90] END bootstrap=False, max_features=50, n_estimators=10;, score=(train=1.000, test=0.950) total time=   0.2s
# [CV 3/5; 86/90] START bootstrap=False, max_features=50, n_estimators=10.........
# [CV 3/5; 86/90] END bootstrap=False, max_features=50, n_estimators=10;, score=(train=1.000, test=0.963) total time=   0.2s
# [CV 4/5; 86/90] START bootstrap=False, max_features=50, n_estimators=10.........
# [CV 4/5; 86/90] END bootstrap=False, max_features=50, n_estimators=10;, score=(train=1.000, test=0.966) total time=   0.2s
# [CV 5/5; 86/90] START bootstrap=False, max_features=50, n_estimators=10.........
# [CV 5/5; 86/90] END bootstrap=False, max_features=50, n_estimators=10;, score=(train=1.000, test=0.957) total time=   0.2s
# [CV 1/5; 87/90] START bootstrap=False, max_features=50, n_estimators=15.........
# [CV 1/5; 87/90] END bootstrap=False, max_features=50, n_estimators=15;, score=(train=1.000, test=0.935) total time=   0.2s
# [CV 2/5; 87/90] START bootstrap=False, max_features=50, n_estimators=15.........
# [CV 2/5; 87/90] END bootstrap=False, max_features=50, n_estimators=15;, score=(train=1.000, test=0.959) total time=   0.3s
# [CV 3/5; 87/90] START bootstrap=False, max_features=50, n_estimators=15.........
# [CV 3/5; 87/90] END bootstrap=False, max_features=50, n_estimators=15;, score=(train=1.000, test=0.966) total time=   0.3s
# [CV 4/5; 87/90] START bootstrap=False, max_features=50, n_estimators=15.........
# [CV 4/5; 87/90] END bootstrap=False, max_features=50, n_estimators=15;, score=(train=1.000, test=0.973) total time=   0.3s
# [CV 5/5; 87/90] START bootstrap=False, max_features=50, n_estimators=15.........
# [CV 5/5; 87/90] END bootstrap=False, max_features=50, n_estimators=15;, score=(train=1.000, test=0.942) total time=   0.2s
# [CV 1/5; 88/90] START bootstrap=False, max_features=50, n_estimators=20.........
# [CV 1/5; 88/90] END bootstrap=False, max_features=50, n_estimators=20;, score=(train=1.000, test=0.937) total time=   0.3s
# [CV 2/5; 88/90] START bootstrap=False, max_features=50, n_estimators=20.........
# [CV 2/5; 88/90] END bootstrap=False, max_features=50, n_estimators=20;, score=(train=1.000, test=0.961) total time=   0.3s
# [CV 3/5; 88/90] START bootstrap=False, max_features=50, n_estimators=20.........
# [CV 3/5; 88/90] END bootstrap=False, max_features=50, n_estimators=20;, score=(train=1.000, test=0.965) total time=   0.3s
# [CV 4/5; 88/90] START bootstrap=False, max_features=50, n_estimators=20.........
# [CV 4/5; 88/90] END bootstrap=False, max_features=50, n_estimators=20;, score=(train=1.000, test=0.970) total time=   0.3s
# [CV 5/5; 88/90] START bootstrap=False, max_features=50, n_estimators=20.........
# [CV 5/5; 88/90] END bootstrap=False, max_features=50, n_estimators=20;, score=(train=1.000, test=0.943) total time=   0.3s
# [CV 1/5; 89/90] START bootstrap=False, max_features=50, n_estimators=25.........
# [CV 1/5; 89/90] END bootstrap=False, max_features=50, n_estimators=25;, score=(train=1.000, test=0.933) total time=   0.3s
# [CV 2/5; 89/90] START bootstrap=False, max_features=50, n_estimators=25.........
# [CV 2/5; 89/90] END bootstrap=False, max_features=50, n_estimators=25;, score=(train=1.000, test=0.957) total time=   0.4s
# [CV 3/5; 89/90] START bootstrap=False, max_features=50, n_estimators=25.........
# [CV 3/5; 89/90] END bootstrap=False, max_features=50, n_estimators=25;, score=(train=1.000, test=0.971) total time=   0.3s
# [CV 4/5; 89/90] START bootstrap=False, max_features=50, n_estimators=25.........
# [CV 4/5; 89/90] END bootstrap=False, max_features=50, n_estimators=25;, score=(train=1.000, test=0.972) total time=   0.4s
# [CV 5/5; 89/90] START bootstrap=False, max_features=50, n_estimators=25.........
# [CV 5/5; 89/90] END bootstrap=False, max_features=50, n_estimators=25;, score=(train=1.000, test=0.948) total time=   0.3s
# [CV 1/5; 90/90] START bootstrap=False, max_features=50, n_estimators=30.........
# [CV 1/5; 90/90] END bootstrap=False, max_features=50, n_estimators=30;, score=(train=1.000, test=0.938) total time=   0.4s
# [CV 2/5; 90/90] START bootstrap=False, max_features=50, n_estimators=30.........
# [CV 2/5; 90/90] END bootstrap=False, max_features=50, n_estimators=30;, score=(train=1.000, test=0.956) total time=   0.4s
# [CV 3/5; 90/90] START bootstrap=False, max_features=50, n_estimators=30.........
# [CV 3/5; 90/90] END bootstrap=False, max_features=50, n_estimators=30;, score=(train=1.000, test=0.966) total time=   0.4s
# [CV 4/5; 90/90] START bootstrap=False, max_features=50, n_estimators=30.........
# [CV 4/5; 90/90] END bootstrap=False, max_features=50, n_estimators=30;, score=(train=1.000, test=0.971) total time=   0.4s
# [CV 5/5; 90/90] START bootstrap=False, max_features=50, n_estimators=30.........
# [CV 5/5; 90/90] END bootstrap=False, max_features=50, n_estimators=30;, score=(train=1.000, test=0.949) total time=   0.4s
# {'bootstrap': False, 'max_features': 10, 'n_estimators': 15}
# RandomForestClassifier(bootstrap=False, max_features=10, n_estimators=15,
#                        n_jobs=-1)
# 0.9812935323383085
# 0.9059139784946236

# %%
save_path = os.path.join(root, "model_name/") + f"random_forest_cepheids_{grid_search_new.best_score_}.model"
joblib.dump(grid_search_new, save_path)
# Out:
# ['F:\\WorkSpace\\Pycharm\\天文项目\\ASAS-Classification_v5\\model_name/random_forest_cepheids_0.9767164179104476.model']

# %%
cvres = grid_search_new.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# 0.9669651741293531 {'max_features': 10, 'n_estimators': 10}
# 0.9741293532338308 {'max_features': 10, 'n_estimators': 15}
# 0.9751243781094528 {'max_features': 10, 'n_estimators': 20}
# 0.976318407960199 {'max_features': 10, 'n_estimators': 25}
# 0.9767164179104476 {'max_features': 10, 'n_estimators': 30}
# 0.9649751243781095 {'max_features': 15, 'n_estimators': 10}
# 0.9701492537313433 {'max_features': 15, 'n_estimators': 15}
# 0.973134328358209 {'max_features': 15, 'n_estimators': 20}
# 0.9739303482587065 {'max_features': 15, 'n_estimators': 25}
# 0.9735323383084576 {'max_features': 15, 'n_estimators': 30}
# 0.9623880597014924 {'max_features': 20, 'n_estimators': 10}
# 0.9699502487562188 {'max_features': 20, 'n_estimators': 15}
# 0.9711442786069652 {'max_features': 20, 'n_estimators': 20}
# 0.9717412935323383 {'max_features': 20, 'n_estimators': 25}
# 0.9741293532338308 {'max_features': 20, 'n_estimators': 30}
# 0.9677611940298508 {'max_features': 25, 'n_estimators': 10}
# 0.9669651741293533 {'max_features': 25, 'n_estimators': 15}
# 0.9709452736318408 {'max_features': 25, 'n_estimators': 20}
# 0.9713432835820894 {'max_features': 25, 'n_estimators': 25}
# 0.9711442786069651 {'max_features': 25, 'n_estimators': 30}
# 0.9639800995024876 {'max_features': 30, 'n_estimators': 10}
# 0.9667661691542289 {'max_features': 30, 'n_estimators': 15}
# 0.9701492537313433 {'max_features': 30, 'n_estimators': 20}
# 0.9703482587064677 {'max_features': 30, 'n_estimators': 25}
# 0.9697512437810945 {'max_features': 30, 'n_estimators': 30}
# 0.9631840796019902 {'max_features': 35, 'n_estimators': 10}
# 0.9669651741293531 {'max_features': 35, 'n_estimators': 15}
# 0.9691542288557213 {'max_features': 35, 'n_estimators': 20}
# 0.9721393034825871 {'max_features': 35, 'n_estimators': 25}
# 0.969950248756219 {'max_features': 35, 'n_estimators': 30}
# 0.961592039800995 {'max_features': 40, 'n_estimators': 10}
# 0.964179104477612 {'max_features': 40, 'n_estimators': 15}
# 0.968955223880597 {'max_features': 40, 'n_estimators': 20}
# 0.9639800995024876 {'max_features': 40, 'n_estimators': 25}
# 0.9669651741293531 {'max_features': 40, 'n_estimators': 30}
# 0.9643781094527363 {'max_features': 45, 'n_estimators': 10}
# 0.9629850746268657 {'max_features': 45, 'n_estimators': 15}
# 0.9649751243781093 {'max_features': 45, 'n_estimators': 20}
# 0.9659701492537314 {'max_features': 45, 'n_estimators': 25}
# 0.9647761194029851 {'max_features': 45, 'n_estimators': 30}
# 0.9580099502487561 {'max_features': 50, 'n_estimators': 10}
# 0.9609950248756218 {'max_features': 50, 'n_estimators': 15}
# 0.9623880597014927 {'max_features': 50, 'n_estimators': 20}
# 0.9669651741293533 {'max_features': 50, 'n_estimators': 25}
# 0.9643781094527364 {'max_features': 50, 'n_estimators': 30}

# %%
# 计算每种特征对分类结果的影响
feature_name = features_drop_unlabel.columns
feature_importances = grid_search_new.best_estimator_.feature_importances_
sorted(zip(feature_importances, feature_name), reverse=True)
# Out:
# [(0.12601571120284158, 'ambient_light'),
#  (0.11910734953437324, 'r21'),
#  (0.0818942847613223, 'period'),
#  (0.04726507061073445, 'r31'),
#  (0.04632582313057719, 'h_1'),
#  (0.040894937760115255, 'slope_per10'),
#  (0.030819654009651764, 'eta'),
#  (0.028723217311932333, 'r41'),
#  (0.026572414912126238, 'phase_cusum'),
#  (0.026068662707511306, 'slope_per90'),
#  (0.02526140209730426, 'skewness'),
#  (0.023784658806753692, 'IQR'),
#  (0.022929998846490694, 'MAD'),
#  (0.021875709726225014, 'theta_w'),
#  (0.021650437674981104, 'variation'),
#  (0.02000014955784285, 'amplitude'),
#  (0.019235961697496792, 'Mm'),
#  (0.019122719728551528, 'l1'),
#  (0.018219907422578098, 'hl_amp_ratio'),
#  (0.017950306702426835, 'std'),
#  (0.014972995347532337, 'r53'),
#  (0.01261653044336245, 'r51'),
#  (0.009567929932679948, 'RoMS'),
#  (0.009012387367914987, 'a2'),
#  (0.008442200729528738, 'phase_eta'),
#  (0.008305350312270214, 'median'),
#  (0.007859240603221334, 'a42'),
#  (0.007832562716921497, 'theta_NXS'),
#  (0.0076874630055793905, 'mean_vmag'),
#  (0.007547742453875128, 'r42'),
#  (0.006897650768766329, 'sem'),
#  (0.0065920086134421884, 'r43'),
#  (0.006486678309196863, 'r52'),
#  (0.00603486940648326, 'sim'),
#  (0.005968652051389322, 'a3'),
#  (0.005846530316497701, 't_test'),
#  (0.005347905403047683, 'stetson_k'),
#  (0.005160603801689355, 'kurtosis'),
#  (0.005121850926012117, 'a4'),
#  (0.005067558054776986, 'b3'),
#  (0.004784996332077342, 'b2'),
#  (0.004762245765838334, 'shapiro_w'),
#  (0.004727772065247193, 'shapiro_log10p'),
#  (0.0043986089811924095, 'b4'),
#  (0.004103257418720493, 'a1'),
#  (0.004047913949514358, 'r54'),
#  (0.003958181117802362, 'p2p'),
#  (0.003925840950387615, 'cusum'),
#  (0.00387169223924846, 'phi42'),
#  (0.0038549743311843947, 'a5'),
#  (0.0036677837488510237, 'phi21'),
#  (0.0031623261828526567, 'b5'),
#  (0.003020093199106345, 'b1'),
#  (0.0029677865062775447, 'phi51'),
#  (0.0025081565873935393, 'phi31'),
#  (0.0023101518568677715, 'b42'),
#  (0.0019690733430772623, 'phi41'),
#  (0.0018720566583365237, 'f_phase')]

# %%
import matplotlib.pyplot as plt

importances = sorted(zip(feature_importances, feature_name), reverse=True)
feature_im = []
feature_n = []
for i in importances:
    feature_im.append(i[0])
    feature_n.append(i[1])
plt.figure(figsize=(20, 10))
indexes = np.arange(len(feature_im))
plt.title("Influence of different indexes on classification accuracy", fontsize=20)
plt.xlabel("Different feature indexes", fontsize=16)
plt.ylabel("Feature importances", fontsize=16)
plt.bar(2 * indexes, feature_im, 2, edgecolor="black", alpha=0.7, color=['r', 'g', 'b', 'y', 'pink'])
plt.xticks(2 * indexes + 2 * 0.2, feature_n, rotation=90)
plt.show()
plt.savefig(f"./output/feature_important/random_forest_cepheids_importance_{grid_search_new.best_score_}.png")

# %%
from my_util.utils import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

y_pred = grid_search_new.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

classes = np.unique(np.concatenate([np.array(y_test), np.array(y_pred)]))
classes = label_encoder.inverse_transform(classes)
print(classes)

save_path = os.path.join(root, "output",
                         "confusion_matrix/") + f"confusion_matrix_random_forest_cepheids_{grid_search_new.best_score_}.png"
plot_confusion_matrix(cm, save_path, classes=classes, title='confusion matrix 5 classes(random forest cepheids)')
# Out:
# ['CWA' 'CWB' 'DCEP' 'DCEPS' 'RVA']

# %%
from sklearn.metrics import recall_score, precision_score, f1_score, classification_report

print(recall_score(y_test, y_pred, average='weighted'))
print(f1_score(y_test, y_pred, average='weighted'))
print(precision_score(y_test, y_pred, average='weighted'))
print(recall_score(y_test, y_pred, average='weighted'))
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
# 0.9247311827956989
# 0.9274843526814953
# 0.9323221152224581
# 0.9247311827956989
#               precision    recall  f1-score   support
#
#          CWA       0.83      0.92      0.87        48
#          CWB       0.53      0.71      0.61        14
#         DCEP       0.98      0.95      0.96       252
#        DCEPS       0.93      0.88      0.90        57
#          RVA       1.00      1.00      1.00         1
#
#     accuracy                           0.92       372
#    macro avg       0.85      0.89      0.87       372
# weighted avg       0.93      0.92      0.93       372
